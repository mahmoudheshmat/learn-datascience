# %% [markdown]
# # Improving Employee Retention: A Research Proposal
#
# ## The problem
# Employers will take one of two approaches to employee retention efforts. Some enforce high turnover rates for a variety of reasons, including not budgeting for proper training or considering that positions are easily re-filled. Other companies invest a lot in their employees and lose some of that investment to attrition. However, there is strong evidence that the latter is still more cost-effective and productive in reaching company goals. [Insert stats here] [Insert story about toyota and the 60 questions a manager must ask him/herself before firing an employee]. Though this proposal utilizes a dataset for IBM employees, theoretically, any interested company can regularly release employee surveys with these same questions and utilize this proposal as a backbone to plan their own retention strategies.
#
#
# ### Data source
# Below, I'm using a dataset that IBM data scientists generated regarding employee attrition rates and a variety of parameters that may be responsible. Survey data is one of the easiest and cost effective means of reporting employee satisfaction rates. Not all of the data is carefully described, so I will make some assumptions and list them below.
#
# Assumptions:
# - attrition is documented at one year after survey release
# - relationship satisfaction is regarding amicable experiences with fellow employees
#
#
# Data: https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset/home
#
# Description
#
# Education 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'
#
# EnvironmentSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobInvolvement
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# PerformanceRating
# 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
#
# RelationshipSatisfaction
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# WorkLifeBalance 1 'Bad' 2 'Good' 3 'Better' 4 'Best'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
df = pd.read_csv('IBM-HR-Employee-Attrition.csv')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## A glance at the data

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel          ...           RelationshipSatisfaction  \
# count  1470.000000          ...                        1470.000000
# mean      2.063946          ...                           2.712245
# std       1.106940          ...                           1.081209
# min       1.000000          ...                           1.000000
# 25%       1.000000          ...                           2.000000
# 50%       2.000000          ...                           3.000000
# 75%       3.000000          ...                           4.000000
# max       5.000000          ...                           4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         1470.0       1470.000000        1470.000000
# mean            80.0          0.793878          11.279592
# std              0.0          0.852077           7.780782
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000           6.000000
# 50%             80.0          1.000000          10.000000
# 75%             80.0          1.000000          15.000000
# max             80.0          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Data cleaning
# There are some aspects of an employees life that IBM cannot control (such as how far a commute to work is), therefore, I will drop all columns that would not be useful in helping IBM retain their employees. Though there are some parameters that may be useful to consider in future hiring, I will drop those as well if it's not helpful information in keeping those already employed. My primary goal here is for maintaining current employee loyalty. However, I will leave some variables that are known to be a source of discrimination in the workplace, such as age. I'm also omitting all measures of pay, except for hourly rates, because they will all provide essentially the same information.

# %%
df = df.loc[:, ['Age', 'Attrition', 'BusinessTravel', 'Department',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'RelationshipSatisfaction',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'StockOptionLevel', 
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
df.describe()
# Out:
#                Age  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count  1470.000000              1470.000000  1470.000000     1470.000000
# mean     36.923810                 2.721769    65.891156        2.729932
# std       9.135373                 1.093082    20.329428        0.711561
# min      18.000000                 1.000000    30.000000        1.000000
# 25%      30.000000                 2.000000    48.000000        2.000000
# 50%      36.000000                 3.000000    66.000000        3.000000
# 75%      43.000000                 4.000000    83.750000        3.000000
# max      60.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# count  1470.000000      1470.000000               1470.000000
# mean      2.063946         2.728571                  2.712245
# std       1.106940         1.102846                  1.081209
# min       1.000000         1.000000                  1.000000
# 25%       1.000000         2.000000                  2.000000
# 50%       2.000000         3.000000                  3.000000
# 75%       3.000000         4.000000                  4.000000
# max       5.000000         4.000000                  4.000000
#
#        PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# count        1470.000000        1470.000000       1470.000000
# mean           15.209524           3.153741          0.793878
# std             3.659938           0.360824          0.852077
# min            11.000000           3.000000          0.000000
# 25%            12.000000           3.000000          0.000000
# 50%            14.000000           3.000000          1.000000
# 75%            18.000000           3.000000          1.000000
# max            25.000000           4.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1470.000000            1470.000000      1470.000000
# mean           11.279592               2.799320         2.761224
# std             7.780782               1.289271         0.706476
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            15.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 3.000000
# max         40.000000           18.000000                15.000000
#
#        YearsWithCurrManager
# count           1470.000000
# mean               4.123129
# std                3.568136
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000

# %% [markdown]
# ## Explore retention rates

# %%
left = df[df.Attrition == 'Yes']
retained = df[df.Attrition=='No']

# %%
left.describe()
# Out:
#               Age  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count  237.000000               237.000000  237.000000      237.000000
# mean    33.607595                 2.464135   65.573840        2.518987
# std      9.689350                 1.169791   20.099958        0.773405
# min     18.000000                 1.000000   31.000000        1.000000
# 25%     28.000000                 1.000000   50.000000        2.000000
# 50%     32.000000                 3.000000   66.000000        3.000000
# 75%     39.000000                 4.000000   84.000000        3.000000
# max     58.000000                 4.000000  100.000000        4.000000
#
#          JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# count  237.000000       237.000000                237.000000
# mean     1.637131         2.468354                  2.599156
# std      0.940594         1.118058                  1.125437
# min      1.000000         1.000000                  1.000000
# 25%      1.000000         1.000000                  2.000000
# 50%      1.000000         3.000000                  3.000000
# 75%      2.000000         3.000000                  4.000000
# max      5.000000         4.000000                  4.000000
#
#        PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# count         237.000000         237.000000        237.000000
# mean           15.097046           3.156118          0.527426
# std             3.770294           0.363735          0.856361
# min            11.000000           3.000000          0.000000
# 25%            12.000000           3.000000          0.000000
# 50%            14.000000           3.000000          0.000000
# 75%            17.000000           3.000000          1.000000
# max            25.000000           4.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count         237.000000             237.000000       237.000000
# mean            8.244726               2.624473         2.658228
# std             7.169204               1.254784         0.816453
# min             0.000000               0.000000         1.000000
# 25%             3.000000               2.000000         2.000000
# 50%             7.000000               2.000000         3.000000
# 75%            10.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count      237.000000          237.000000               237.000000
# mean         5.130802            2.902954                 1.945148
# std          5.949984            3.174827                 3.153077
# min          0.000000            0.000000                 0.000000
# 25%          1.000000            0.000000                 0.000000
# 50%          3.000000            2.000000                 1.000000
# 75%          7.000000            4.000000                 2.000000
# max         40.000000           15.000000                15.000000
#
#        YearsWithCurrManager
# count            237.000000
# mean               2.852321
# std                3.143349
# min                0.000000
# 25%                0.000000
# 50%                2.000000
# 75%                5.000000
# max               14.000000

# %%
retained.describe()
# Out:
#                Age  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count  1233.000000              1233.000000  1233.000000     1233.000000
# mean     37.561233                 2.771290    65.952149        2.770479
# std       8.888360                 1.071132    20.380754        0.692050
# min      18.000000                 1.000000    30.000000        1.000000
# 25%      31.000000                 2.000000    48.000000        2.000000
# 50%      36.000000                 3.000000    66.000000        3.000000
# 75%      43.000000                 4.000000    83.000000        3.000000
# max      60.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# count  1233.000000      1233.000000               1233.000000
# mean      2.145985         2.778589                  2.733982
# std       1.117933         1.093277                  1.071603
# min       1.000000         1.000000                  1.000000
# 25%       1.000000         2.000000                  2.000000
# 50%       2.000000         3.000000                  3.000000
# 75%       3.000000         4.000000                  4.000000
# max       5.000000         4.000000                  4.000000
#
#        PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# count        1233.000000        1233.000000       1233.000000
# mean           15.231144           3.153285          0.845093
# std             3.639511           0.360408          0.841985
# min            11.000000           3.000000          0.000000
# 25%            12.000000           3.000000          0.000000
# 50%            14.000000           3.000000          1.000000
# 75%            18.000000           3.000000          1.000000
# max            25.000000           4.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1233.000000            1233.000000      1233.000000
# mean           11.862936               2.832928         2.781022
# std             7.760719               1.293585         0.681907
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            16.000000               3.000000         3.000000
# max            38.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1233.000000         1233.000000              1233.000000
# mean         7.369019            4.484185                 2.234388
# std          6.096298            3.649402                 3.234762
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          6.000000            3.000000                 1.000000
# 75%         10.000000            7.000000                 3.000000
# max         37.000000           18.000000                15.000000
#
#        YearsWithCurrManager
# count           1233.000000
# mean               4.367397
# std                3.594116
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000

# %%
print("Attrition rates of IBM employees: ", len(left)/len(retained))
# Out:
# Attrition rates of IBM employees:  0.1922141119221411

# %% [markdown]
# Perhaps this attrition rate differs across departments.

# %%
depts = df.Department.unique()
print("Departments included: ", depts)
# Out:
# Departments included:  ['Sales' 'Research & Development' 'Human Resources']

# %%
print("Attrition rates per department: ")
for dept in depts:
    print(dept, ":  ", len(left[left.Department == dept]) / len(df[df.Department == dept]))
# Out:
# Attrition rates per department:
# Sales :   0.2062780269058296
# Research & Development :   0.1383975026014568
# Human Resources :   0.19047619047619047

# %% [markdown]
# Interesting, worthwhile to see why R&D may have significantly better retention than Sales and HR and perhaps try to model that environment. Below I will look at departmental differences in the variables.

# %%
left['Department'].value_counts()
# Out:
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: Department, dtype: int64

# %%
retained['Department'].value_counts()
# Out:
# Research & Development    828
# Sales                     354
# Human Resources            51
# Name: Department, dtype: int64

# %% [markdown]
# General rule of thumb in statistics requires a sample to be of at least size 30, which the attrition group of HR does not meet. For this reason, I likely will not be able to conclude anything reliable regarding that department and will instead focus on R&D and Sales.
#
#
# Below I will run some statistical tests (Mann-Whitney) that does not assume normality across the samples. These will help steer focus on factors directly influencing attrition rates.

# %%
depts = ['Research & Development', 'Sales']

# %%
for dept in depts:
    print(dept, "\naverage differences in attrition versus retention:\Attrition\n", left[left.Department == dept].mean()) 
    print("Retention\n", retained[retained.Department==dept].mean())
    print("\n")
# Out:
# Research & Development
# average differences in attrition versus retention:\Attrition
#  Age                         33.473684
# EnvironmentSatisfaction      2.473684
# HourlyRate                  66.834586
# JobInvolvement               2.556391
# JobLevel                     1.421053
# JobSatisfaction              2.458647
# RelationshipSatisfaction     2.518797
# PercentSalaryHike           15.308271
# PerformanceRating            3.195489
# StockOptionLevel             0.518797
# TotalWorkingYears            8.082707
# TrainingTimesLastYear        2.586466
# WorkLifeBalance              2.578947
# YearsAtCompany               4.954887
# YearsInCurrentRole           2.706767
# YearsSinceLastPromotion      1.872180
# YearsWithCurrManager         2.849624
# dtype: float64
# Retention
#  Age                         37.615942
# EnvironmentSatisfaction      2.787440
# HourlyRate                  66.060386
# JobInvolvement               2.771739
# JobLevel                     2.066425
# JobSatisfaction              2.769324
# RelationshipSatisfaction     2.739130
# PercentSalaryHike           15.288647
# PerformanceRating            3.157005
# StockOptionLevel             0.850242
# TotalWorkingYears           11.865942
# TrainingTimesLastYear        2.826087
# WorkLifeBalance              2.748792
# YearsAtCompany               7.171498
# YearsInCurrentRole           4.387681
# YearsSinceLastPromotion      2.179952
# YearsWithCurrManager         4.282609
# dtype: float64
#
#
# Sales
# average differences in attrition versus retention:\Attrition
#  Age                         34.260870
# EnvironmentSatisfaction      2.467391
# HourlyRate                  64.097826
# JobInvolvement               2.467391
# JobLevel                     1.989130
# JobSatisfaction              2.521739
# RelationshipSatisfaction     2.652174
# PercentSalaryHike           14.956522
# PerformanceRating            3.108696
# StockOptionLevel             0.500000
# TotalWorkingYears            8.760870
# TrainingTimesLastYear        2.750000
# WorkLifeBalance              2.739130
# YearsAtCompany               5.510870
# YearsInCurrentRole           3.304348
# YearsSinceLastPromotion      2.195652
# YearsWithCurrManager         3.032609
# dtype: float64
# Retention
#  Age                         37.135593
# EnvironmentSatisfaction      2.734463
# HourlyRate                  65.889831
# JobInvolvement               2.762712
# JobLevel                     2.324859
# JobSatisfaction              2.810734
# RelationshipSatisfaction     2.706215
# PercentSalaryHike           15.132768
# PerformanceRating            3.144068
# StockOptionLevel             0.844633
# TotalWorkingYears           11.714689
# TrainingTimesLastYear        2.872881
# WorkLifeBalance              2.836158
# YearsAtCompany               7.745763
# YearsInCurrentRole           4.793785
# YearsSinceLastPromotion      2.395480
# YearsWithCurrManager         4.593220
# dtype: float64

# %%
columns = ['Age',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'RelationshipSatisfaction',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'StockOptionLevel', 
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']
for dept in depts:
    print(dept, "\n")
    for column in columns:
        print(column)
        print(mannwhitneyu(left[left.Department == dept][column], retained[retained.Department==dept][column]))
        print("\n")
    print("\n")
# Out:
# Research & Development
#
# Age
# MannwhitneyuResult(statistic=39127.0, pvalue=4.021915896592603e-08)
#
#
# EnvironmentSatisfaction
# MannwhitneyuResult(statistic=47004.0, pvalue=0.0024195682172469574)
#
#
# Gender
# MannwhitneyuResult(statistic=50520.0, pvalue=0.035483500964093063)
#
#
# HourlyRate
# MannwhitneyuResult(statistic=53829.0, pvalue=0.3391228846797934)
#
#
# JobInvolvement
# MannwhitneyuResult(statistic=47015.5, pvalue=0.001109931481513788)
#
#
# JobLevel
# MannwhitneyuResult(statistic=35511.0, pvalue=1.1558304688415182e-12)
#
#
# JobRole
# MannwhitneyuResult(statistic=53875.0, pvalue=0.34066704778281653)
#
#
# JobSatisfaction
# MannwhitneyuResult(statistic=46465.5, pvalue=0.001326854008861614)
#
#
# RelationshipSatisfaction
# MannwhitneyuResult(statistic=49358.0, pvalue=0.023232927765835226)
#
#
# OverTime
# MannwhitneyuResult(statistic=37526.5, pvalue=1.8349947964310142e-14)
#
#
# PercentSalaryHike
# MannwhitneyuResult(statistic=53529.0, pvalue=0.30194619509368814)
#
#
# PerformanceRating
# MannwhitneyuResult(statistic=52943.0, pvalue=0.13214031142387156)
#
#
# StockOptionLevel
# MannwhitneyuResult(statistic=41608.5, pvalue=4.817415207256589e-07)
#
#
# TotalWorkingYears
# MannwhitneyuResult(statistic=36920.0, pvalue=4.678325220120867e-10)
#
#
# TrainingTimesLastYear
# MannwhitneyuResult(statistic=49508.5, pvalue=0.025132419584523943)
#
#
# WorkLifeBalance
# MannwhitneyuResult(statistic=49832.5, pvalue=0.02245714226844965)
#
#
# YearsAtCompany
# MannwhitneyuResult(statistic=38589.5, pvalue=1.313461042545828e-08)
#
#
# YearsInCurrentRole
# MannwhitneyuResult(statistic=38095.5, pvalue=3.5428416223729834e-09)
#
#
# YearsSinceLastPromotion
# MannwhitneyuResult(statistic=49004.5, pvalue=0.016828293208398275)
#
#
# YearsWithCurrManager
# MannwhitneyuResult(statistic=40880.0, pvalue=6.765860722517784e-07)
#
#
#
#
# Sales
#
# Age
# MannwhitneyuResult(statistic=13250.0, pvalue=0.0029242406290699643)
#
#
# EnvironmentSatisfaction
# MannwhitneyuResult(statistic=14143.5, pvalue=0.022047017055247756)
#
#
# Gender
# MannwhitneyuResult(statistic=16064.0, pvalue=0.40794408971014895)
#
#
# HourlyRate
# MannwhitneyuResult(statistic=15455.5, pvalue=0.2260702169160403)
#
#
# JobInvolvement
# MannwhitneyuResult(statistic=13269.0, pvalue=0.000831053330718446)
#
#
# JobLevel
# MannwhitneyuResult(statistic=12856.5, pvalue=0.0003242948700410706)
#
#
# JobRole
# MannwhitneyuResult(statistic=12014.5, pvalue=2.9651989966555446e-07)
#
#
# JobSatisfaction
# MannwhitneyuResult(statistic=13890.5, pvalue=0.012009527981127381)
#
#
# RelationshipSatisfaction
# MannwhitneyuResult(statistic=15745.0, pvalue=0.3059395494750431)
#
#
# OverTime
# MannwhitneyuResult(statistic=11468.0, pvalue=1.2023175767740195e-08)
#
#
# PercentSalaryHike
# MannwhitneyuResult(statistic=15884.0, pvalue=0.3575109210908822)
#
#
# PerformanceRating
# MannwhitneyuResult(statistic=15708.0, pvalue=0.18998832359140028)
#
#
# StockOptionLevel
# MannwhitneyuResult(statistic=11622.0, pvalue=2.260618225086881e-06)
#
#
# TotalWorkingYears
# MannwhitneyuResult(statistic=12159.5, pvalue=8.732891758035838e-05)
#
#
# TrainingTimesLastYear
# MannwhitneyuResult(statistic=15711.0, pvalue=0.29220736042767165)
#
#
# WorkLifeBalance
# MannwhitneyuResult(statistic=15264.0, pvalue=0.14248671056764328)
#
#
# YearsAtCompany
# MannwhitneyuResult(statistic=11655.0, pvalue=1.2494313156832914e-05)
#
#
# YearsInCurrentRole
# MannwhitneyuResult(statistic=12386.0, pvalue=0.00017165972044350146)
#
#
# YearsSinceLastPromotion
# MannwhitneyuResult(statistic=15846.5, pvalue=0.33992930456840276)
#
#
# YearsWithCurrManager
# MannwhitneyuResult(statistic=11912.5, pvalue=3.0008383492693836e-05)

# %% [markdown]
# Both Sales and R&D had significant differences in these factors between attrition and retention groups:
# - age
# - environment satisfaction
# - job involvement
# - job level
# - job satisfaction
# - overtime
# - stock option level
# - total working years
# - years at company
# - years in current role
# - years with current manager
#
# R&D had additional differences:
# - gender
# - relationship satisfaction
# - training times last year
# - work life balance
# - years since last promotion
#
# Sales had additional differences:
# - job role

# %%
df_rnd = df[df.Department=='Research & Development']
df_rnd.head()
# Out:
#    Age Attrition     BusinessTravel              Department  \
# 1   49        No  Travel_Frequently  Research & Development
# 2   37       Yes      Travel_Rarely  Research & Development
# 3   33        No  Travel_Frequently  Research & Development
# 4   27        No      Travel_Rarely  Research & Development
# 5   32        No  Travel_Frequently  Research & Development
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
# 5                        4    Male          79               3         1
#
#                  JobRole          ...           PercentSalaryHike  \
# 1     Research Scientist          ...                          23
# 2  Laboratory Technician          ...                          15
# 3     Research Scientist          ...                          11
# 4  Laboratory Technician          ...                          12
# 5  Laboratory Technician          ...                          13
#
#    PerformanceRating StockOptionLevel  TotalWorkingYears  \
# 1                  4                1                 10
# 2                  3                0                  7
# 3                  3                0                  8
# 4                  3                1                  6
# 5                  3                0                  8
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
# 5                      2                2               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
# 5                        3                     6
#
# [5 rows x 23 columns]

# %%
fig, axs = plt.subplots(ncols=2,nrows=1)

sns.boxplot(x='Attrition', y='RelationshipSatisfaction', data=df_rnd, ax=axs[0])
sns.boxplot(x='Attrition', y='YearsSinceLastPromotion', data=df_rnd, ax=axs[1])
plt.show()

# %% [markdown]
# ## Rollout plan
# IBM has many offices, select 2 that are most similar (i.e. 2 bustling cities or 2 suburb areas with similar department sizes and similar attrition rates). select one office at random to be our test group for an A/B test. we will use this to then determine what our

# %%
print("Attrition rates by gender: ")
print("Male: ", len(left[left.Gender == 'Male']) / len(df[df.Gender == 'Male']))
print("Female: ", len(left[left.Gender=='Female']) / len(df[df.Gender=='Female']))
# Out:
# Attrition rates by gender:
# Male:  0.17006802721088435
# Female:  0.14795918367346939

# %% [markdown]
# Do a ttest//mannwhitney to see if this is significant

# %%
print("Retention rates in R&D by happiness with colleagues (between 1-4): ")
print("Attrition: ", left[left.Department=='Research & Development'].RelationshipSatisfaction.mean())
print("Retention: ", retained[retained.Department=='Research & Development'].RelationshipSatisfaction.mean())
# Out:
# Retention rates in R&D by happiness with colleagues (between 1-4):
# Attrition:  2.518796992481203
# Retention:  2.739130434782609

# %%
print("Retention rates by happiness with colleagues (between 1-4): ")
print("Attrition: ", left.RelationshipSatisfaction.mean())
print("Retention: ", retained.RelationshipSatisfaction.mean())
# Out:
# Retention rates by happiness with colleagues (between 1-4):
# Attrition:  2.5991561181434597
# Retention:  2.7339821573398218

# %% [markdown]
# Is this one significant?

# %%
sns.heatmap(df.corr(),
           xticklabels=df.corr().columns,
           yticklabels=df.corr().columns)

plt.show()

# %%
fig, axs = plt.subplots(ncols=2,nrows=1)

sns.boxplot(x='Attrition', y='YearsSinceLastPromotion', data=df, ax=axs[0])
sns.boxplot(x='Attrition', y='TrainingTimesLastYear', data=df, ax=axs[1])
plt.show()

# %% [markdown]
# This was unexpected - there is a greater spread of time since last promotion in the retained group, indicating recent promotions is not a good attrition prevention method.
#
# Amount of training does not appear to be an indicator, either.

# %%
fig, axs = plt.subplots(ncols=2,nrows=1)

sns.boxplot(x='Attrition', y='PercentSalaryHike', data=df, ax=axs[0])
sns.boxplot(x='Attrition', y='JobLevel', data=df, ax=axs[1])
plt.show()

# %%
sns.boxplot(x='Attrition', y='YearsWithCurrManager', data=df)
plt.show()

# %% [markdown]
# Bingo - perhaps focusing on manager retention will prevent general employee attrition rates.

# %%
sns.distplot(df.PercentSalaryHike)

# %%
sns.distplot(df.Age)
