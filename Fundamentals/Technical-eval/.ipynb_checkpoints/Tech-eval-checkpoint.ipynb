# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('plane_crashes_data.csv')

# %%
df.describe()
# Out:
#              month         year       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000
# mean      6.554079  1981.927279    35.817276    25.816537
# std       3.532468    16.709136    54.306779    42.599461
# min       1.000000  1950.000000     0.000000     0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000
# 50%       7.000000  1983.000000    15.000000     9.000000
# 75%      10.000000  1997.000000    44.000000    29.000000
# max      12.000000  2009.000000   644.000000   583.000000

# %%
df.columns
# Out:
# Index(['month', 'hour', 'year', 'location', 'operator', 'route', 'type',
#        'aboard', 'fatalities', 'summary'],
#       dtype='object')

# %%
type(df.year)
# Out:
# pandas.core.series.Series

# %%
# df 8009 is the dataframe containing data from years 1980 - 2009
df8009 = df[(df['year']>= 1980) & (df['year']<= 2009)]

# %%
df8009.head()
# Out:
#       month hour  year                                    location  \
# 1240      1    1  1980                       Over the AtlantiOcean
# 1241      1   14  1980                            Shungnak, Alaska
# 1242      1   19  1980  Elburz Mtns., near Laskarak, Markazi, Iran
# 1243      1    6  1980                        Near Mandalay, Burma
# 1244      2    8  1980                         Leeville, Louisiana
#
#                                  operator                          route  \
# 1240                      Private charter       Shreveport - Baton Rouge
# 1241                   Ambler Air Service         Ambler, AK - Kobuk, AK
# 1242               Iran National Airlines             Babol Sar - Tehran
# 1243  Military - Union of Burma Air Force             Mandalay - Rangoon
# 1244              Rotor Airs In- Air Taxi  Leeville, LA - Grand Isle, LA
#
#                      type  aboard  fatalities  \
# 1240  Cessna 441 Conquest       2           2
# ...

# %%
df8009.describe()
# Out:
#              month         year      aboard   fatalities
# count  1469.000000  1469.000000  1469.00000  1469.000000
# mean      6.567733  1995.346494    36.87066    24.932607
# std       3.486888     8.076045    61.35977    45.951019
# min       1.000000  1980.000000     0.00000     0.000000
# 25%       3.000000  1989.000000     4.00000     3.000000
# 50%       7.000000  1996.000000    11.00000     7.000000
# 75%       9.000000  2002.000000    39.00000    22.000000
# max      12.000000  2009.000000   524.00000   520.000000

# %%
df5009 = df[(df['year']>=1950) & (df['year']<=2009)]

# %%
df5009.describe()
# Out:
#              month         year       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000
# mean      6.554079  1981.927279    35.817276    25.816537
# std       3.532468    16.709136    54.306779    42.599461
# min       1.000000  1950.000000     0.000000     0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000
# 50%       7.000000  1983.000000    15.000000     9.000000
# 75%      10.000000  1997.000000    44.000000    29.000000
# max      12.000000  2009.000000   644.000000   583.000000

# %%
df5009.month.value_counts()
# Out:
# 1     255
# 12    252
# 3     251
# 8     239
# 7     234
# 11    230
# 9     228
# 10    224
# 2     209
# 4     204
# 6     202
# 5     181
# Name: month, dtype: int64

# %%
df.fatalities.value_counts()
# Out:
# 2      315
# 3      247
# 4      179
# 1      162
# 5      134
# 6      108
# 10      68
# 7       64
# 8       63
# 9       54
# 11      50
# 0       49
# 13      43
# 18      42
# 16      40
# 21      38
# 14      37
# 20      36
# 23      35
# 17      34
# 12      31
# 15      28
# 25      28
# 19      26
# 24      25
# 28      24
# 30      23
# 26      23
# 29      22
# 34      22
#       ...
# 171      1
# 181      1
# 187      1
# 189      1
# 191      1
# 213      1
# 259      1
# 261      1
# 120      1
# 520      1
# 140      1
# 144      1
# 146      1
# 158      1
# 166      1
# 170      1
# 178      1
# 180      1
# 188      1
# 196      1
# 200      1
# 228      1
# 230      1
# 234      1
# 256      1
# 217      1
# 264      1
# 290      1
# 346      1
# 583      1
# Name: fatalities, Length: 189, dtype: int64

# %%
df['percent_fatalities'] = df.fatalities / df.aboard

# %%
df.head()
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
#
#                         operator                          route  \
# 0  Military - Bolivian Air Force      Valle grande - Cochabamba
# 1      Northwest Orient Airlines  Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.               Llandow - Dublin
# 3      Military - U.S. Air Force            Philippines - Japan
# 4      Military - U.S. Air Force              Bermuda - England
#
#                type  aboard  fatalities  \
# 0      Douglas C-47      32          32
# 1        Martin 202      13          13
# 2  Avro 689 Tudor 5      83          80
# 3     Douglas C-54D      35          35
# 4       Boeing B-29      16          16
#
# ...

# %%
df.describe()
# Out:
#              month         year       aboard   fatalities  percent_fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000         2708.000000
# mean      6.554079  1981.927279    35.817276    25.816537            0.823132
# std       3.532468    16.709136    54.306779    42.599461            0.308131
# min       1.000000  1950.000000     0.000000     0.000000            0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000            0.750000
# 50%       7.000000  1983.000000    15.000000     9.000000            1.000000
# 75%      10.000000  1997.000000    44.000000    29.000000            1.000000
# max      12.000000  2009.000000   644.000000   583.000000            1.000000
