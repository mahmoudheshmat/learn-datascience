# %% [markdown]
# As a capstone to this fundamentals course, prepare an Analytic Report and Research Proposal on a dataset of your choosing. Your Report should accomplish these three goals:
#
#     Describe your dataset. Describe and explore your dataset in the initial section of your Report. What does your data contain and what is its background? Where does it come from? Why is it interesting or significant? Conduct summary statistics and produce visualizations for the particular variables from the dataset that you will use.
#
#     Ask and answer analytic questions. Ask three analytic questions and answer each one with a combination of statistics and visualizations. These analytic questions can focus on individuals behaviors or comparisons of the population.
#
#     Propose further research. Lastly, make a proposal for a realistic future research project on this dataset that would use some data science techniques you'd like to learn in the bootcamp. Just like your earlier questions, your research proposal should present one or more clear questions. Then you should describe the techniques you would apply in order to arrive at an answer.
#
# Report guidelines
#
# Keep these guidelines in mind as you draft your Report:
#
#     Length. Your Report should be three to five pages long with visualizations. Short and clear is better than long and opaque.
#     Structure. Pay attention to the narrative structure of your Report. Each section should flow into the next and make a logical, readable text. Don't simply create a list of bullet points or present code without explanation.
#
#
#
#     http://insideairbnb.com/get-the-data.html
#      https://www.apartmentlist.com/rentonomics/rental-price-data/

# %% [markdown]
# # AirBnB hosting: all it's cracked up to be?
# ## Analytics report and research proposal
#
# By Cindy Barrientos
#
# ### Introduction
# (((Describe the problem)))
# ...
# ....
# .....

# %% [markdown]
# theme: report for someone wanting to build a side income renting out airbnb in Portland, OR
#
# 1. how much can one expect to make on airbnb?
#     how much can one make on airbnb vs traditional renting?
# 2. how can one maximize their profits on airbnb?
#     links between: neighborhood and price (are room types confounding?), number of reviews//reviews per month an price, room type and price, availability over the course of a year and price
# 3. how much does it cost to pay off an apartment/house, how long would it take to pay off property with airbnb rentals?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
pd.options.display.max_columns=30

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
#plt.rcParams({'font.size': 22})

# %% [markdown]
# ## Describe the datasets

# %% [markdown]
# ## AirBnB data

# %%
full_OR_airbnb = pd.read_csv('listings.csv.gz', compression='gzip')

# %%
full_OR_airbnb.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
full_OR_airbnb.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   7893   https://www.airbnb.com/rooms/7893  20181107122123   2018-11-07
# 1  12899  https://www.airbnb.com/rooms/12899  20181107122123   2018-11-07
# 2  16688  https://www.airbnb.com/rooms/16688  20181107122123   2018-11-07
# 3  25200  https://www.airbnb.com/rooms/25200  20181107122123   2018-11-07
# 4  26203  https://www.airbnb.com/rooms/26203  20181107122123   2018-11-07
#
#                                                 name  \
# 0                           North Williams 2brm Home
# 1  Alberta Arts 2 bedroom suite, charming 1906 house
# 2     Beautiful condo in downtown Pearl, NW Portland
# 3             Flamenco Dream :: hip mississippi ave.
# 4                     Bluebird @ hip mississippi ave
#
#                                              summary  \
# 0  Located on Williams bike corridor, some of Por...
# 1  Settle in to a space of your own. You'll have ...
# 2  Newly remodeled 2 bedroom (3 queen beds), 2 fu...
# 3  If you are an Urban Farming pioneer, enthusias...
# 4  If you are an Urban Farming pioneer, enthusias...
#
#                                                space  \
# 0  This NE Portland 2 bedroom home is located jus...
# 1  We live in a neighborhood of beautiful gardens...
# 2  - Fully furnished condo with high ceilings, bi...
# 3  The large farmhouse is surrounded by magical u...
# 4  The large farmhouse is surrounded by magical u...
#
#                                          description experiences_offered  \
# 0  Located on Williams bike corridor, some of Por...                none
# 1  Settle in to a space of your own. You'll have ...                none
# 2  Newly remodeled 2 bedroom (3 queen beds), 2 fu...                none
# 3  If you are an Urban Farming pioneer, enthusias...                none
# 4  If you are an Urban Farming pioneer, enthusias...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  We're within walking distance of a grocery and...
# 2  Easily one of Portland’s most desirable neighb...
# 3  Tierra Soul is located in the fun and hip Miss...
# 4  We are located in the fun and hip Mississippi ...
#
#                                                notes  \
# 0                                                NaN
# 1  We welcome musicians and even have a guitar fo...
# 2  - Smoking is strictly prohibited - Must be abl...
# 3  QUIET HOURS: (9pm -7am) We have guests from al...
# 4  QUIET HOURS: (9pm -7am) We have guests from al...
#
#                                              transit  \
# 0                                                NaN
# 1  Parking is readily available in front of our h...
# 2  Walking distance to the public Light Rail, bus...
# 3  We are a 5 minute drive, and 10 minute MAX rid...
# 4  We are a 5 minute drive, and 10 minute MAX rid...
#
#                                               access  \
# 0                                                NaN
# 1  Guests have the whole upstairs, two bedrooms, ...
# 2  Our guests enjoy entire home to themselves. Di...
# 3                                                NaN
# 4                                                NaN
#
#                                          interaction  \
# 0                                                NaN
# 1  We let our guests determine their level of int...
# 2  Our guests can reach us via phone, text or email.
# 3                                                NaN
# 4                                                NaN
#
#                                          house_rules        ...         \
# 0                                                NaN        ...
# 1  Please no smoking. The space is not child-proo...        ...
# 2                                                NaN        ...
# 3  quiet-ish hours: 9pm - 7am     this means we a...        ...
# 4  quiet-ish hours: 9pm - 7am     this means we a...        ...
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                        9.0                   10.0
# 4                       10.0                    9.0
#
#   review_scores_communication  review_scores_location  review_scores_value  \
# 0                        10.0                    10.0                 10.0
# 1                        10.0                    10.0                 10.0
# 2                        10.0                    10.0                  9.0
# 3                        10.0                    10.0                  9.0
# 4                        10.0                    10.0                  9.0
#
#   requires_license                license                 jurisdiction_names  \
# 0                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
# 1                t    14-218887-000-00-HO  {OREGON," MULTNOMAH"," PORTLAND"}
# 2                t  2008-190040-000-00-RS  {OREGON," MULTNOMAH"," PORTLAND"}
# 3                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
# 4                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     flexible
# 1                f                        f                     moderate
# 2                t                        f                     moderate
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture  require_guest_phone_verification  \
# 0                             f                                 f
# 1                             f                                 f
# 2                             f                                 f
# 3                             f                                 f
# 4                             f                                 f
#
#   calculated_host_listings_count reviews_per_month
# 0                              1              0.02
# 1                              1              4.67
# 2                              1              2.37
# 3                              6              0.33
# 4                              6              0.27
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Cleaning the data
#
# There is a lot more data here than is necessary or that I can even work with. Will do  bit of cleaning and refining to prepare for analytics
# 1. removed excess columns
# 2. fixed price column such that the '%' and ',' symbols are dropped, then turn into a floating point (or should i instead round up to int?)
# 3. removed listings that are valued at greater than USD500/night
#
# *so many columns, maybe i should make new sub-dataframes with themes such as reviews?

# %%
airbnb = full_OR_airbnb.drop(columns=['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate', 'host_total_listings_count', 'neighbourhood_group_cleansed', 
                                              'requires_license', 'license', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 
                                              'calendar_last_scraped', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'street', 
                                              'host_verifications', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'listing_url', 'scrape_id',
                                              'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
                                              'house_rules', 'picture_url', 'host_id', 'host_url', 'square_feet', 'weekly_price', 'monthly_price', 'neighbourhood'])
                                                # dropped because only 61 of 5000 listings have this info
                                                # only using price/night, not considering weekly/monthly discounts
airbnb.describe()
# Out:
#                  id  host_listings_count  accommodates    bathrooms  \
# count  5.317000e+03          5312.000000   5317.000000  5314.000000
# mean   1.531575e+07            12.256589      3.435960     1.230335
# std    8.481055e+06           114.287981      1.898449     0.510583
# min    7.893000e+03             0.000000      1.000000     0.000000
# 25%    7.959145e+06             1.000000      2.000000     1.000000
# 50%    1.625721e+07             1.000000      3.000000     1.000000
# 75%    2.188217e+07             2.000000      4.000000     1.000000
# max    2.986167e+07          1305.000000     24.000000     5.000000
#
#           bedrooms         beds  guests_included  minimum_nights  \
# count  5315.000000  5316.000000      5317.000000     5317.000000
# mean      1.359172     1.869451         1.811360        4.221930
# std       0.901567     1.230026         1.292145       10.049577
# min       0.000000     0.000000         1.000000        1.000000
# 25%       1.000000     1.000000         1.000000        1.000000
# 50%       1.000000     2.000000         1.000000        2.000000
# 75%       2.000000     2.000000         2.000000        2.000000
# max       8.000000    16.000000        15.000000      222.000000
#
#        maximum_nights  number_of_reviews  review_scores_rating  \
# count     5317.000000        5317.000000           4846.000000
# mean       489.343051          60.934173             96.931077
# std        534.905799          81.961679              4.410958
# min          1.000000           0.000000             20.000000
# 25%         21.000000           6.000000             96.000000
# 50%         90.000000          29.000000             98.000000
# 75%       1125.000000          84.000000            100.000000
# max       5000.000000         865.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4844.000000                4843.000000
# mean                 9.880058                   9.784844
# std                  0.426587                   0.548327
# min                  2.000000                   2.000000
# 25%                 10.000000                  10.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4841.000000                  4842.000000
# mean                9.940921                     9.932879
# std                 0.302573                     0.341687
# min                 5.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             4841.000000          4841.000000
# mean                 9.790126             9.739103
# std                  0.477763             0.551386
# min                  4.000000             2.000000
# 25%                 10.000000            10.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     5317.000000        4877.000000
# mean                         2.123190           3.013443
# std                          4.193996           2.920180
# min                          1.000000           0.010000
# 25%                          1.000000           0.780000
# 50%                          1.000000           2.380000
# 75%                          2.000000           4.450000
# max                         41.000000          58.160000

# %%
airbnb.price = [x.strip('$') for x in airbnb.price]
airbnb.price = airbnb.price.str.replace(',', '')

airbnb.price.unique()
# Out:
# array(['175.00', '65.00', '275.00', '49.00', '200.00', '29.00', '70.00',
#        '61.00', '78.00', '95.00', '60.00', '90.00', '425.00', '40.00',
#        '75.00', '239.00', '55.00', '69.00', '43.00', '59.00', '165.00',
#        '23.00', '62.00', '83.00', '110.00', '81.00', '100.00', '99.00',
#        '150.00', '76.00', '128.00', '85.00', '500.00', '50.00', '256.00',
#        '599.00', '44.00', '124.00', '155.00', '180.00', '28.00', '48.00',
#        '250.00', '199.00', '1950.00', '225.00', '67.00', '120.00',
#        '80.00', '105.00', '185.00', '115.00', '125.00', '38.00', '89.00',
#        '109.00', '227.00', '72.00', '58.00', '299.00', '30.00', '39.00',
#        '98.00', '389.00', '300.00', '57.00', '20.00', '146.00', '130.00',
#        '135.00', '190.00', '295.00', '325.00', '68.00', '159.00', '79.00',
#        '45.00', '156.00', '88.00', '35.00', '248.00', '212.00', '63.00',
#        '84.00', '56.00', '64.00', '42.00', '169.00', '375.00', '108.00',
#        '101.00', '400.00', '74.00', '160.00', '37.00', '245.00', '119.00',
#        '92.00', '195.00', '149.00', '1500.00', '140.00', '189.00',
#        '47.00', '350.00', '145.00', '215.00', '53.00', '151.00', '129.00',
#        '209.00', '280.00', '54.00', '675.00', '349.00', '106.00',
#        '132.00', '318.00', '107.00', '136.00', '118.00', '41.00', '93.00',
#        '420.00', '499.00', '1499.00', '82.00', '94.00', '113.00',
#        '249.00', '285.00', '66.00', '73.00', '36.00', '137.00', '235.00',
#        '234.00', '192.00', '147.00', '134.00', '595.00', '114.00',
#        '178.00', '219.00', '97.00', '52.00', '86.00', '142.00', '77.00',
#        '475.00', '477.00', '179.00', '315.00', '143.00', '999.00',
#        '123.00', '139.00', '33.00', '450.00', '495.00', '34.00', '32.00',
#        '8400.00', '229.00', '104.00', '91.00', '122.00', '560.00',
#        '87.00', '117.00', '210.00', '71.00', '1002.00', '96.00', '18.00',
#        '103.00', '162.00', '320.00', '170.00', '138.00', '290.00',
#        '126.00', '121.00', '335.00', '269.00', '490.00', '233.00',
#        '223.00', '46.00', '240.00', '650.00', '188.00', '399.00',
#        '385.00', '31.00', '260.00', '274.00', '220.00', '241.00',
#        '133.00', '230.00', '197.00', '25.00', '15.00', '11.00', '365.00',
#        '10.00', '270.00', '153.00', '112.00', '252.00', '265.00',
#        '345.00', '102.00', '127.00', '24.00', '111.00', '176.00',
#        '449.00', '183.00', '22.00', '161.00', '259.00', '177.00',
#        '131.00', '191.00', '337.00', '164.00', '181.00', '700.00',
#        '575.00', '26.00', '158.00', '218.00', '289.00', '232.00',
#        '141.00', '186.00', '196.00', '202.00', '2000.00', '205.00',
#        '279.00', '157.00', '390.00', '253.00', '550.00', '167.00',
#        '800.00', '329.00', '975.00', '1200.00', '380.00', '600.00',
#        '369.00', '198.00', '168.00', '0.00', '1000.00', '174.00',
#        '395.00', '148.00', '154.00', '116.00', '51.00', '21.00', '319.00',
#        '330.00', '144.00', '355.00', '27.00', '2835.00', '1835.00',
#        '310.00', '288.00', '340.00', '228.00', '900.00', '255.00',
#        '172.00'], dtype=object)

# %%
airbnb.dtypes
airbnb['price'] = airbnb['price'].astype('float')

# %%
airbnb.price.max()
# Out:
# 8400.0

# %% [markdown]
# I don't believe there is really an AirBnB listing available for $8400. As it turns out in searching the listing URL, the cost is 84/night:

# %%
full_OR_airbnb.loc[airbnb['price']==8400]
# Out:
#           id                           listing_url       scrape_id  \
# 836  4684661  https://www.airbnb.com/rooms/4684661  20181107122123
#
#     last_scraped                              name summary  \
# 836   2018-11-07  Charming quiet bohemian getaway!     NaN
#
#                                                  space  \
# 836  You have your own private entrance into the fl...
#
#                                            description experiences_offered  \
# 836  You have your own private entrance into the fl...                none
#
#                                  neighborhood_overview notes  \
# 836  A great place to walk around, fruit trees and ...   NaN
#
#                                                transit  \
# 836  Public transportattion is nearby and I have un...
#
#                                                 access  \
# 836  You have the entire upstairs which consists of...
#
#                                            interaction  \
# 836  Since I live in the house you have ready acces...
#
#                                            house_rules        ...         \
# 836  No Smoking - I have had new carpets put in as ...        ...
#
#      review_scores_cleanliness  review_scores_checkin  \
# 836                       10.0                   10.0
#
#     review_scores_communication  review_scores_location  review_scores_value  \
# 836                        10.0                    10.0                 10.0
#
#     requires_license              license                 jurisdiction_names  \
# 836                t  15-131548-000-00-HO  {OREGON," MULTNOMAH"," PORTLAND"}
#
#     instant_bookable is_business_travel_ready cancellation_policy  \
# 836                t                        f            moderate
#
#     require_guest_profile_picture  require_guest_phone_verification  \
# 836                             f                                 f
#
#     calculated_host_listings_count reviews_per_month
# 836                              1              3.42
#
# [1 rows x 96 columns]

# %%
airbnb.at[836, 'price'] = 84.00
airbnb.price.max()
# Out:
# 2835.0

# %% [markdown]
# The next highest listing is no longer available so I cannot verify. There are a handful of listings today 12/18/2018 that are above USD1500, but they are meant as retreats or special events. I'm not interested in seeing investment opportunities in such large and expensive properties, so I'll limit my data up to $500 per night.

# %%
airbnb = airbnb[airbnb['price']<=500]
airbnb.price.describe()
# Out:
# count    5285.000000
# mean      110.112772
# std        71.466615
# min         0.000000
# 25%        65.000000
# 50%        90.000000
# 75%       129.000000
# max       500.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Exploring the data: continuous variables
# - what parameters influence price?

# %%
# continuous
airbnb_cont = airbnb[['id', 'price', 'host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'guests_included',
                              'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
                              'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
                              'review_scores_value', 'calculated_host_listings_count', 'reviews_per_month']].copy()
airbnb_cont.head()
# Out:
#       id  price  host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0   7893  175.0                  1.0             3        1.0       2.0   2.0
# 1  12899   65.0                  1.0             3        1.0       2.0   2.0
# 2  16688  275.0                  1.0             8        2.0       2.0   3.0
# 3  25200   49.0                  7.0             2        1.0       1.0   1.0
# 4  26203   49.0                  7.0             2        1.0       1.0   1.0
#
#    guests_included  minimum_nights  maximum_nights  number_of_reviews  \
# 0                1               3              30                  2
# 1                2               2             730                500
# 2                6               2             365                 44
# 3                1               7            1125                 34
# 4                1               3            1125                 28
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                 100.0                    10.0                       10.0
# 1                  98.0                    10.0                       10.0
# 2                  97.0                    10.0                       10.0
# 3                  93.0                     9.0                        9.0
# 4                  92.0                     9.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                    9.0                         10.0                    10.0
#
#    review_scores_value  calculated_host_listings_count  reviews_per_month
# 0                 10.0                               1               0.02
# 1                 10.0                               1               4.67
# 2                  9.0                               1               2.37
# 3                  9.0                               6               0.33
# 4                  9.0                               6               0.27

# %%
plt.scatter(x='review_scores_rating', y='price', data=airbnb)
plt.xlabel("Review scores rating")
plt.ylabel("Price per night")
plt.yticks(np.arange(0, 600, step=50))
plt.show()

# %% [markdown]
# <b>Comment</b> It looks like what you pay for is not necessarily what you get. Though the highest rated listing has the highest reviews, 100% positive score is found throughout the entire price spectrum.

# %%
airbnb.columns
# Out:
# Index(['id', 'host_name', 'host_since', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_listings_count',
#        'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
airbnb.boxplot(column='price', by='zipcode')

# %%
# discrete
airbnb_cat = full_OR_airbnb.drop(columns=[airbnb_cont.columns])
airbnb_cat.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-77e6dfc65e84> in <module>()
#       1 # discrete
# ----> 2 airbnb_cat = full_OR_airbnb.drop(columns=[airbnb_cont.columns])
#       3 airbnb_cat.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels [('id', 'host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'guests_included', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'reviews_per_month')] not contained in axis"

# %%
full_OR_airbnb.host_response_time.unique()
# Out:
# array([nan, 'within an hour', 'within a few hours', 'within a day',
#        'a few days or more'], dtype=object)

# %%
airbnb.neighbourhood_cleansed.value_counts().plot(kind="bar")
plt.xlabel('Neighbourhood')
plt.ylabel('Number of listings')
plt.title('AirBnB listings per neighborhood')
plt.show()

# %% [markdown]
# <b>Note:</b> Lots of different neighborhood classifications. Might want to combine some of these for it to be of use, or use jurisdiction

# %%
airbnb.jurisdiction_names.value_counts().plot(kind='bar')

# %% [markdown]
# <b>Note:</b> Okay jurisdiction won't be useful either - almost everything is in Multnomah county

# %%
airbnb = full_OR_airbnb.drop(columns='jurisdiction_names')

# %%
airbnb.zipcode.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# <b>Note:</b> These have a more digestible amount of categories. I could even remove the last 10 or so because there isn't enough airbnb love there. If going by zip code, it might be difficult to compare to apartmentlist and zillow that combines by city name.

# %%
airbnb.bed_type.value_counts()
# Out:
# Real Bed         5214
# Futon              57
# Pull-out Sofa      27
# Airbed             10
# Couch               9
# Name: bed_type, dtype: int64

# %%
airbnb.loc[airbnb['bed_type']=='Couch']
# Out:
#             id         host_name  host_since  host_response_time  \
# 72      293584  Summer + Patrick  2011-12-16  a few days or more
# 74      296946            Margot  2013-05-09      within an hour
# 117     573191            Deanna  2009-08-18        within a day
# 689    3969896           Michael  2014-08-26                 NaN
# 1156   6892357            Eugene  2015-03-18      within an hour
# 1372   8167765             Anesa  2010-08-30      within an hour
# 2116  13415468          Benjamin  2015-09-14      within an hour
# 3089  18720162            Stuart  2015-10-07                 NaN
# 3617  20554660           Stewart  2017-08-10                 NaN
#
#      host_response_rate host_is_superhost  host_listings_count  \
# 72                  33%                 f                  1.0
# 74                  98%                 f                  7.0
# 117                 75%                 f                  1.0
# 689                 NaN                 f                  1.0
# 1156               100%                 t                  2.0
# 1372               100%                 t                  1.0
# 2116               100%                 f                  4.0
# 3089                NaN                 f                  9.0
# 3617                NaN                 f                  1.0
#
#      host_has_profile_pic host_identity_verified        neighbourhood  \
# 72                      t                      t                  NaN
# 74                      t                      t                Kerns
# 117                     t                      f                  NaN
# 689                     t                      f   Old Town/Chinatown
# 1156                    t                      f              Buckman
# 1372                    t                      t       Rose City Park
# 2116                    t                      t             Richmond
# 3089                    t                      t  Powellhurst-Gilbert
# 3617                    t                      f            Sunnyside
#
#      neighbourhood_cleansed      city state zipcode property_type  \
# 72                  Buckman  Portland    OR   97214          Loft
# 74                    Kerns  Portland    OR   97232         Other
# 117               Irvington  Portland    OR   97212     Apartment
# 689      Old Town/Chinatown  Portland    OR   97209     Apartment
# 1156                Buckman  Portland    OR   97214         House
# 1372         Rose City Park  Portland    OR   97215     Apartment
# 2116               Richmond  Portland    OR   97214       Cottage
# 3089    Powellhurst-Gilbert  Portland    OR   97236         House
# 3617              Sunnyside  Portland    OR   97214         House
#
#             ...         last_review  review_scores_rating  \
# 72          ...          2012-10-24                 100.0
# 74          ...          2014-01-29                 100.0
# 117         ...          2017-07-23                  87.0
# 689         ...                 NaN                   NaN
# 1156        ...          2018-10-14                  92.0
# 1372        ...          2018-11-06                  99.0
# 2116        ...          2018-07-23                  94.0
# 3089        ...          2018-10-07                  92.0
# 3617        ...                 NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 72                      10.0                        9.0
# 74                      10.0                       10.0
# 117                      9.0                        8.0
# 689                      NaN                        NaN
# 1156                     9.0                       10.0
# 1372                    10.0                       10.0
# 2116                    10.0                        9.0
# 3089                     9.0                        9.0
# 3617                     NaN                        NaN
#
#       review_scores_checkin review_scores_communication  \
# 72                      9.0                        10.0
# 74                     10.0                        10.0
# 117                     9.0                        10.0
# 689                     NaN                         NaN
# 1156                    9.0                         9.0
# 1372                   10.0                        10.0
# 2116                   10.0                        10.0
# 3089                   10.0                        10.0
# 3617                    NaN                         NaN
#
#      review_scores_location review_scores_value instant_bookable  \
# 72                     10.0                 9.0                f
# 74                     10.0                10.0                f
# 117                     9.0                 9.0                f
# 689                     NaN                 NaN                f
# 1156                   10.0                 9.0                f
# 1372                   10.0                10.0                f
# 2116                   10.0                10.0                t
# 3089                    9.0                 9.0                t
# 3617                    NaN                 NaN                f
#
#      is_business_travel_ready          cancellation_policy  \
# 72                          f                     moderate
# 74                          f  strict_14_with_grace_period
# 117                         f                     flexible
# 689                         f                     flexible
# 1156                        f                     flexible
# 1372                        f                     moderate
# 2116                        f                     moderate
# 3089                        f                     moderate
# 3617                        f                     flexible
#
#      require_guest_profile_picture  require_guest_phone_verification  \
# 72                               f                                 f
# 74                               f                                 f
# 117                              f                                 f
# 689                              f                                 f
# 1156                             f                                 f
# 1372                             f                                 f
# 2116                             f                                 f
# 3089                             f                                 f
# 3617                             f                                 f
#
#       calculated_host_listings_count  reviews_per_month
# 72                                 1               0.14
# 74                                 7               0.02
# 117                                1               2.00
# 689                                1                NaN
# 1156                               2               0.27
# 1372                               1               3.30
# 2116                               3               0.64
# 3089                               9               5.28
# 3617                               1                NaN
#
# [9 rows x 46 columns]

# %%
# how do i filter for a series of values?
full_OR_airbnb.loc[(airbnb['zipcode']=='97034') | (airbnb['zipcode']=='97211-6358') | (airbnb['zipcode']=='97225') |
           (airbnb['zipcode']=='97035') | (airbnb['zipcode']=='97068') | (airbnb['zipcode']=='97222') |
           (airbnb['zipcode']=='97231') | (airbnb['zipcode']=='97229') | (airbnb['zipcode']=='97230') |
           (airbnb['zipcode']=='97233')]
# Out:
#             id               host_name  host_since  host_response_time  \
# 49      203462                  Alfred  2011-07-29      within an hour
# 286    1280971                    Isil  2013-06-08  a few days or more
# 305    1373521                    John  2013-07-12                 NaN
# 447    2346466                    Kara  2011-09-24                 NaN
# 460    2407080                    Jeff  2014-02-15                 NaN
# 542    3040690                 Marlene  2014-05-12      within an hour
# 643    3649423                   Chris  2013-12-27      within an hour
# 690    3985028                    Kara  2011-09-24                 NaN
# 691    3985039                    Kara  2011-09-24                 NaN
# 921    5154353                   Sarah  2014-09-27                 NaN
# 940    5267715                  Joshua  2012-03-26                 NaN
# 1086   6346680        Franz And Teresa  2015-05-10  within a few hours
# 1169   6975773                  Angela  2015-06-23      within an hour
# 1295   7759293                  Alissa  2015-08-07        within a day
# 1312   7870115                 Heather  2015-08-14                 NaN
# 1503   8989294                  Lesley  2015-09-14  within a few hours
# 1521   9095149                   Sally  2012-05-06      within an hour
# 1524   9107116                Stefanie  2015-10-26      within an hour
# 1544   9212033                   Amine  2015-07-20                 NaN
# 1573   9365410                     N A  2015-11-09      within an hour
# 1681  10023551                    Alan  2014-01-28                 NaN
# 1874  11868205                    Nile  2013-11-19      within an hour
# 1878  11906587  Evolve Vacation Rental  2015-11-09        within a day
# 2015  12900085                   Nancy  2015-08-01                 NaN
# 2018  12913646                  Raissa  2013-04-24      within an hour
# 2165  13624774                 Harriet  2014-07-23      within an hour
# 2173  13675204                    Nile  2013-11-19      within an hour
# 2176  13687017  Evolve Vacation Rental  2015-11-09        within a day
# 2201  13829943                  Rachel  2016-05-24      within an hour
# 2218  13900856                  Eliane  2016-07-07                 NaN
# ...        ...                     ...         ...                 ...
# 4374  24059689                 Yohanes  2018-02-15                 NaN
# 4394  24159448                Veronica  2018-04-02                 NaN
# 4414  24289562   Stephanie & Kristofer  2018-04-08      within an hour
# 4470  24645143                   Keith  2017-12-21      within an hour
# 4492  24754870                    Atty  2014-01-31      within an hour
# 4563  25139487                  Cheryl  2014-08-15      within an hour
# 4608  25327826       Yurii And Kseniia  2018-05-24      within an hour
# 4724  26131483                 Heather  2014-11-15                 NaN
# 4745  26236022                   Dylan  2017-10-20      within an hour
# 4746  26236460                  Amanda  2014-01-17                 NaN
# 4756  26307138                Michelle  2017-04-15      within an hour
# 4796  26541236                    Ying  2016-06-26      within an hour
# 4818  26669193                    Riad  2018-07-06      within an hour
# 4828  26737734                   Bruce  2018-07-09      within an hour
# 4887  27113255                      Ha  2016-12-17      within an hour
# 4895  27141658          James & Ashley  2013-07-24      within an hour
# 4901  27168340       Yurii And Kseniia  2018-05-24      within an hour
# 4989  27611081                 Viorica  2018-08-08      within an hour
# 4999  27654805                 Viorica  2018-08-08      within an hour
# 5012  27729267                  Dianna  2014-06-09      within an hour
# 5023  27789196                    Anne  2018-08-16      within an hour
# 5036  27900888                    Anne  2018-08-16      within an hour
# 5077  28207462                    Anne  2018-08-16      within an hour
# 5128  28630639            Geri & Ralph  2016-01-05      within an hour
# 5169  28909519                  Shampa  2018-03-14      within an hour
# 5187  29018743                   Becca  2018-10-04      within an hour
# 5239  29342557                    Jeff  2014-04-15                 NaN
# 5300  29804161                 Kristen  2017-01-31      within an hour
# 5309  29833487                 Kristen  2017-01-31      within an hour
# 5314  29860751                 Kristen  2017-01-31      within an hour
#
#      host_response_rate host_is_superhost  host_listings_count  \
# 49                 100%                 t                  1.0
# 286                  0%                 f                  1.0
# 305                 NaN                 t                  1.0
# 447                 NaN                 f                  5.0
# 460                 NaN                 f                  1.0
# 542                100%                 f                  3.0
# 643                100%                 f                  1.0
# 690                 NaN                 f                  5.0
# 691                 NaN                 f                  5.0
# 921                 NaN                 f                  1.0
# 940                 NaN                 f                  1.0
# 1086                80%                 f                  1.0
# 1169               100%                 t                  1.0
# 1295                90%                 t                  2.0
# 1312                NaN                 f                  2.0
# 1503               100%                 f                  2.0
# 1521               100%                 f                  1.0
# 1524               100%                 t                  1.0
# 1544                NaN                 f                  1.0
# 1573               100%                 t                  1.0
# 1681                NaN                 f                  1.0
# 1874               100%                 t                  2.0
# 1878                50%                 f                 36.0
# 2015                NaN                 f                  1.0
# 2018               100%                 f                  1.0
# 2165               100%                 t                  1.0
# 2173               100%                 t                  2.0
# 2176                50%                 f                 36.0
# 2201               100%                 f                  1.0
# 2218                NaN                 f                  1.0
# ...                 ...               ...                  ...
# 4374                NaN                 f                  1.0
# 4394                NaN                 f                  1.0
# 4414                90%                 t                  1.0
# 4470               100%                 t                  1.0
# 4492               100%                 t                  1.0
# 4563               100%                 t                  2.0
# 4608               100%                 f                  2.0
# 4724                NaN                 f                  1.0
# 4745               100%                 f                  2.0
# 4746                NaN                 f                  1.0
# 4756               100%                 t                  1.0
# 4796               100%                 f                  1.0
# 4818               100%                 f                  1.0
# 4828               100%                 t                  1.0
# 4887               100%                 f                  1.0
# 4895               100%                 t                  1.0
# 4901               100%                 f                  2.0
# 4989               100%                 f                  2.0
# 4999               100%                 f                  2.0
# 5012               100%                 f                  1.0
# 5023               100%                 f                  3.0
# 5036               100%                 f                  3.0
# 5077               100%                 f                  3.0
# 5128               100%                 f                  1.0
# 5169               100%                 f                  1.0
# 5187               100%                 f                  1.0
# 5239                NaN                 f                  1.0
# 5300               100%                 f                  3.0
# 5309               100%                 f                  3.0
# 5314               100%                 f                  3.0
#
#      host_has_profile_pic host_identity_verified neighbourhood  \
# 49                      t                      t   Forest Park
# 286                     t                      t   Forest Park
# 305                     t                      t        Wilkes
# 447                     t                      t     Hazelwood
# 460                     t                      t   Forest Park
# 542                     t                      f           NaN
# 643                     t                      t       Russell
# 690                     t                      t     Hazelwood
# 691                     t                      t     Hazelwood
# 921                     t                      t  Eastmoreland
# 940                     t                      t  Eastmoreland
# 1086                    t                      t         Argay
# 1169                    t                      f         Argay
# 1295                    t                      t   Forest Park
# 1312                    t                      t   Forest Park
# 1503                    t                      t   Forest Park
# 1521                    t                      t   Forest Park
# 1524                    t                      t   Forest Park
# 1544                    t                      f         Argay
# 1573                    t                      t        Wilkes
# 1681                    t                      f  Eastmoreland
# 1874                    t                      t     Woodstock
# 1878                    t                      f  Eastmoreland
# 2015                    t                      f        Wilkes
# 2018                    t                      t      Glenfair
# 2165                    t                      t      Glenfair
# 2173                    t                      t     Woodstock
# 2176                    t                      f  Eastmoreland
# 2201                    t                      t      Glenfair
# 2218                    t                      f     Mill Park
# ...                   ...                    ...           ...
# 4374                    t                      f     Hazelwood
# 4394                    t                      f        Wilkes
# 4414                    t                      f     Mill Park
# 4470                    t                      f           NaN
# 4492                    t                      f     Concordia
# 4563                    t                      t     Mill Park
# 4608                    t                      f           NaN
# 4724                    t                      f   Forest Park
# 4745                    t                      f     Hazelwood
# 4746                    t                      t     Hazelwood
# 4756                    t                      t       Russell
# 4796                    t                      t   Forest Park
# 4818                    t                      f   Forest Park
# 4828                    t                      f   Forest Park
# 4887                    t                      t     Hazelwood
# 4895                    t                      f     Hazelwood
# 4901                    t                      f           NaN
# 4989                    t                      f       Russell
# 4999                    t                      f       Russell
# 5012                    t                      f        Wilkes
# 5023                    t                      f     Mill Park
# 5036                    t                      f     Mill Park
# 5077                    t                      f     Mill Park
# 5128                    t                      f       Russell
# 5169                    t                      f        Wilkes
# 5187                    t                      f     Mill Park
# 5239                    t                      t  Arnold Creek
# 5300                    t                      f     Hazelwood
# 5309                    t                      f     Hazelwood
# 5314                    t                      f     Hazelwood
#
#        neighbourhood_cleansed         city state     zipcode property_type  \
# 49                Forest Park     Portland    OR       97229    Guesthouse
# 286         Northwest Heights     Portland    OR       97229         House
# 305                 Hazelwood     Portland    OR       97230    Guesthouse
# 447                Centennial     Portland    OR       97233   Condominium
# 460               Forest Park     Portland    OR       97229         House
# 542               Forest Park     Portland    OR       97231         House
# 643                   Russell     Portland    OR       97230         House
# 690                Centennial     Portland    OR       97233     Apartment
# 691                Centennial     Portland    OR       97233     Apartment
# 921   Ardenwald-Johnson Creek     Portland    OR       97222         House
# 940   Ardenwald-Johnson Creek     Portland    OR       97222         House
# 1086                    Argay     Portland    OR       97230         House
# 1169                    Argay     Portland    OR       97230         House
# 1295                  Linnton     Portland    OR       97231   Condominium
# 1312        Northwest Heights     Portland    OR       97229         House
# 1503              Forest Park     Portland    OR       97229         House
# 1521        Northwest Heights     Portland    OR       97229         House
# 1524        Northwest Heights     Portland    OR       97229   Guest suite
# 1544                    Argay     Portland    OR       97230         House
# 1573                   Wilkes     Portland    OR       97230         House
# 1681  Ardenwald-Johnson Creek     Portland    OR       97222         House
# 1874  Ardenwald-Johnson Creek     Portland    OR       97222     Apartment
# 1878  Ardenwald-Johnson Creek     Portland    OR       97222     Apartment
# 2015                   Wilkes     Portland    OR       97230         House
# 2018                 Glenfair     Portland    OR       97233     Apartment
# 2165                 Glenfair     Portland    OR       97230       Cottage
# 2173  Ardenwald-Johnson Creek     Portland    OR       97222     Apartment
# 2176  Ardenwald-Johnson Creek    Milwaukie    OR       97222     Apartment
# 2201                 Glenfair     Portland    OR       97233         House
# 2218                Mill Park     Portland    OR       97233   Condominium
# ...                       ...          ...   ...         ...           ...
# 4374                Hazelwood     Portland    OR       97230         House
# 4394                   Wilkes     Portland    OR       97230         House
# 4414                Mill Park     Portland    OR       97233         House
# 4470             Arnold Creek  Lake Oswego    OR       97034         House
# 4492                Concordia     Portland    OR  97211-6358    Guesthouse
# 4563                Mill Park     Portland    OR       97233         House
# 4608               Centennial     Portland    OR       97233   Guest suite
# 4724        Northwest Heights     Portland    OR       97229     Townhouse
# 4745                Hazelwood     Portland    OR       97233         House
# 4746                Hazelwood     Portland    OR       97233     Apartment
# 4756                  Russell     Portland    OR       97230         House
# 4796        Northwest Heights     Portland    OR       97229         House
# 4818                  Linnton     Portland    OR       97231         House
# 4828              Forest Park     Portland    OR       97231     Camper/RV
# 4887                Hazelwood     Portland    OR       97233         House
# 4895                Hazelwood     Portland    OR       97233     Camper/RV
# 4901               Centennial     Portland    OR       97233   Guest suite
# 4989                  Russell     Portland    OR       97230         House
# 4999                  Russell     Portland    OR       97230         House
# 5012                   Wilkes     Portland    OR       97230   Guest suite
# 5023                Mill Park     Portland    OR       97233         House
# 5036                Mill Park     Portland    OR       97233         House
# 5077                Mill Park     Portland    OR       97233         House
# 5128                  Russell     Portland    OR       97230         House
# 5169                   Wilkes     Portland    OR       97230         House
# 5187                Mill Park     Portland    OR       97233         House
# 5239             Arnold Creek  Lake Oswego    OR       97035   Condominium
# 5300               Centennial     Portland    OR       97233         House
# 5309               Centennial     Portland    OR       97233         House
# 5314               Centennial     Portland    OR       97233         House
#
#             ...        review_scores_rating  review_scores_accuracy  \
# 49          ...                        93.0                     9.0
# 286         ...                        91.0                    10.0
# 305         ...                        98.0                    10.0
# 447         ...                        95.0                    10.0
# 460         ...                       100.0                    10.0
# 542         ...                       100.0                    10.0
# 643         ...                        89.0                     9.0
# 690         ...                         NaN                     NaN
# 691         ...                        98.0                    10.0
# 921         ...                        98.0                    10.0
# 940         ...                        92.0                     8.0
# 1086        ...                        98.0                    10.0
# 1169        ...                        99.0                    10.0
# 1295        ...                        96.0                    10.0
# 1312        ...                       100.0                    10.0
# 1503        ...                         NaN                     NaN
# 1521        ...                        95.0                    10.0
# 1524        ...                        99.0                    10.0
# 1544        ...                        97.0                    10.0
# 1573        ...                        98.0                    10.0
# 1681        ...                       100.0                    10.0
# 1874        ...                        94.0                    10.0
# 1878        ...                         NaN                     NaN
# 2015        ...                       100.0                    10.0
# 2018        ...                        86.0                     9.0
# 2165        ...                       100.0                    10.0
# 2173        ...                        97.0                    10.0
# 2176        ...                       100.0                    10.0
# 2201        ...                        97.0                    10.0
# 2218        ...                        94.0                     9.0
# ...         ...                         ...                     ...
# 4374        ...                        88.0                     9.0
# 4394        ...                       100.0                     9.0
# 4414        ...                        98.0                    10.0
# 4470        ...                        99.0                    10.0
# 4492        ...                        99.0                    10.0
# 4563        ...                        97.0                    10.0
# 4608        ...                        95.0                    10.0
# 4724        ...                        80.0                    10.0
# 4745        ...                        93.0                    10.0
# 4746        ...                       100.0                    10.0
# 4756        ...                       100.0                    10.0
# 4796        ...                       100.0                    10.0
# 4818        ...                         NaN                     NaN
# 4828        ...                       100.0                    10.0
# 4887        ...                       100.0                    10.0
# 4895        ...                        97.0                    10.0
# 4901        ...                        97.0                    10.0
# 4989        ...                        80.0                    10.0
# 4999        ...                        95.0                    10.0
# 5012        ...                         NaN                     NaN
# 5023        ...                        87.0                     9.0
# 5036        ...                        94.0                    10.0
# 5077        ...                       100.0                    10.0
# 5128        ...                       100.0                    10.0
# 5169        ...                        90.0                    10.0
# 5187        ...                        91.0                    10.0
# 5239        ...                         NaN                     NaN
# 5300        ...                         NaN                     NaN
# 5309        ...                         NaN                     NaN
# 5314        ...                         NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 49                         10.0                   10.0
# 286                        10.0                   10.0
# 305                        10.0                   10.0
# 447                        10.0                   10.0
# 460                        10.0                   10.0
# 542                        10.0                   10.0
# 643                         9.0                    9.0
# 690                         NaN                    NaN
# 691                        10.0                   10.0
# 921                        10.0                   10.0
# 940                         8.0                   10.0
# 1086                       10.0                   10.0
# 1169                       10.0                   10.0
# 1295                       10.0                   10.0
# 1312                       10.0                   10.0
# 1503                        NaN                    NaN
# 1521                       10.0                   10.0
# 1524                       10.0                   10.0
# 1544                       10.0                   10.0
# 1573                       10.0                   10.0
# 1681                       10.0                   10.0
# 1874                        9.0                   10.0
# 1878                        NaN                    NaN
# 2015                       10.0                   10.0
# 2018                        9.0                   10.0
# 2165                       10.0                   10.0
# 2173                        9.0                   10.0
# 2176                       10.0                   10.0
# 2201                       10.0                   10.0
# 2218                       10.0                    9.0
# ...                         ...                    ...
# 4374                        9.0                    9.0
# 4394                       10.0                   10.0
# 4414                       10.0                   10.0
# 4470                       10.0                   10.0
# 4492                       10.0                   10.0
# 4563                       10.0                   10.0
# 4608                       10.0                   10.0
# 4724                       10.0                    8.0
# 4745                        9.0                   10.0
# 4746                       10.0                   10.0
# 4756                       10.0                   10.0
# 4796                       10.0                   10.0
# 4818                        NaN                    NaN
# 4828                       10.0                   10.0
# 4887                       10.0                   10.0
# 4895                       10.0                   10.0
# 4901                       10.0                   10.0
# 4989                        9.0                    9.0
# 4999                        9.0                   10.0
# 5012                        NaN                    NaN
# 5023                        9.0                    9.0
# 5036                       10.0                   10.0
# 5077                       10.0                   10.0
# 5128                        9.0                   10.0
# 5169                       10.0                   10.0
# 5187                        9.0                   10.0
# 5239                        NaN                    NaN
# 5300                        NaN                    NaN
# 5309                        NaN                    NaN
# 5314                        NaN                    NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 49                           10.0                    9.0                 9.0
# 286                           9.0                    9.0                 9.0
# 305                          10.0                    9.0                10.0
# 447                          10.0                    9.0                 9.0
# 460                          10.0                   10.0                10.0
# 542                          10.0                   10.0                10.0
# 643                          10.0                    9.0                 9.0
# 690                           NaN                    NaN                 NaN
# 691                          10.0                   10.0                10.0
# 921                          10.0                    9.0                10.0
# 940                          10.0                    9.0                 9.0
# 1086                         10.0                   10.0                10.0
# 1169                         10.0                   10.0                10.0
# 1295                         10.0                    9.0                10.0
# 1312                         10.0                   10.0                10.0
# 1503                          NaN                    NaN                 NaN
# 1521                         10.0                   10.0                 9.0
# 1524                         10.0                   10.0                10.0
# 1544                         10.0                   10.0                10.0
# 1573                         10.0                    9.0                10.0
# 1681                         10.0                   10.0                10.0
# 1874                         10.0                    9.0                10.0
# 1878                          NaN                    NaN                 NaN
# 2015                         10.0                   10.0                10.0
# 2018                         10.0                    8.0                 9.0
# 2165                         10.0                   10.0                10.0
# 2173                         10.0                   10.0                10.0
# 2176                         10.0                   10.0                10.0
# 2201                         10.0                    9.0                10.0
# 2218                          9.0                    9.0                 9.0
# ...                           ...                    ...                 ...
# 4374                          9.0                   10.0                 9.0
# 4394                         10.0                   10.0                10.0
# 4414                         10.0                    9.0                10.0
# 4470                         10.0                   10.0                10.0
# 4492                         10.0                   10.0                10.0
# 4563                         10.0                   10.0                10.0
# 4608                         10.0                    9.0                10.0
# 4724                          6.0                    8.0                 4.0
# 4745                         10.0                    9.0                10.0
# 4746                         10.0                   10.0                10.0
# 4756                         10.0                   10.0                10.0
# 4796                         10.0                   10.0                10.0
# 4818                          NaN                    NaN                 NaN
# 4828                         10.0                   10.0                10.0
# 4887                         10.0                    9.0                10.0
# 4895                         10.0                    9.0                10.0
# 4901                         10.0                   10.0                 9.0
# 4989                          9.0                   10.0                10.0
# 4999                         10.0                   10.0                10.0
# 5012                          NaN                    NaN                 NaN
# 5023                          9.0                    9.0                 9.0
# 5036                         10.0                    9.0                10.0
# 5077                         10.0                    9.0                10.0
# 5128                         10.0                   10.0                10.0
# 5169                         10.0                    7.0                 9.0
# 5187                         10.0                    9.0                10.0
# 5239                          NaN                    NaN                 NaN
# 5300                          NaN                    NaN                 NaN
# 5309                          NaN                    NaN                 NaN
# 5314                          NaN                    NaN                 NaN
#
#                        jurisdiction_names instant_bookable  \
# 49      {OREGON," MULTNOMAH"," PORTLAND"}                f
# 286     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 305     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 447     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 460   {OREGON," Washington County"," OR"}                f
# 542     {OREGON," MULTNOMAH"," PORTLAND"}                t
# 643     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 690     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 691     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 921                              {OREGON}                f
# 940     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1086    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1169    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1295    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1312    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1503    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1521    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1524    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1544    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1573    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1681    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1874                 {OREGON," PORTLAND"}                f
# 1878                             {OREGON}                f
# 2015    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2018    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2165    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2173                 {OREGON," PORTLAND"}                f
# 2176                             {OREGON}                f
# 2201    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2218    {OREGON," MULTNOMAH"," PORTLAND"}                t
# ...                                   ...              ...
# 4374    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4394    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4414    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4470    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4492    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4563    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4608    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4724  {OREGON," Washington County"," OR"}                f
# 4745    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4746    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4756    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4796    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4818    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4828    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4887    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4895    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4901    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4989    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4999    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5012    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5023    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5036    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5077    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5128    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5169    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5187    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5239                {OREGON," MULTNOMAH"}                t
# 5300    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5309    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5314    {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#      is_business_travel_ready          cancellation_policy  \
# 49                          f  strict_14_with_grace_period
# 286                         f                     moderate
# 305                         f  strict_14_with_grace_period
# 447                         f  strict_14_with_grace_period
# 460                         f  strict_14_with_grace_period
# 542                         f                     moderate
# 643                         f                     moderate
# 690                         f                     flexible
# 691                         f  strict_14_with_grace_period
# 921                         f                     flexible
# 940                         f  strict_14_with_grace_period
# 1086                        f  strict_14_with_grace_period
# 1169                        f                     moderate
# 1295                        f  strict_14_with_grace_period
# 1312                        f                     flexible
# 1503                        f  strict_14_with_grace_period
# 1521                        f  strict_14_with_grace_period
# 1524                        f                     flexible
# 1544                        f  strict_14_with_grace_period
# 1573                        f                     moderate
# 1681                        f                     flexible
# 1874                        f                     flexible
# 1878                        f  strict_14_with_grace_period
# 2015                        f                     flexible
# 2018                        f  strict_14_with_grace_period
# 2165                        f                     flexible
# 2173                        f                     flexible
# 2176                        f  strict_14_with_grace_period
# 2201                        f                     moderate
# 2218                        f                     moderate
# ...                       ...                          ...
# 4374                        f                     moderate
# 4394                        f                     flexible
# 4414                        f                     moderate
# 4470                        f                     flexible
# 4492                        f                     moderate
# 4563                        f                     moderate
# 4608                        f                     flexible
# 4724                        f                     flexible
# 4745                        f  strict_14_with_grace_period
# 4746                        f                     flexible
# 4756                        f                     flexible
# 4796                        f  strict_14_with_grace_period
# 4818                        f                     moderate
# 4828                        f                     moderate
# 4887                        f                     flexible
# 4895                        f                     moderate
# 4901                        f                     flexible
# 4989                        f                     flexible
# 4999                        f                     flexible
# 5012                        f                     flexible
# 5023                        f                     flexible
# 5036                        f                     flexible
# 5077                        f                     flexible
# 5128                        f                     flexible
# 5169                        f                     flexible
# 5187                        f                     flexible
# 5239                        f                     flexible
# 5300                        f  strict_14_with_grace_period
# 5309                        f  strict_14_with_grace_period
# 5314                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 49                               f                                f
# 286                              t                                t
# 305                              f                                f
# 447                              f                                f
# 460                              f                                f
# 542                              f                                f
# 643                              f                                f
# 690                              f                                f
# 691                              f                                f
# 921                              f                                f
# 940                              f                                f
# 1086                             f                                f
# 1169                             f                                f
# 1295                             f                                f
# 1312                             f                                f
# 1503                             f                                f
# 1521                             f                                f
# 1524                             f                                f
# 1544                             f                                f
# 1573                             f                                f
# 1681                             f                                f
# 1874                             f                                f
# 1878                             f                                f
# 2015                             f                                f
# 2018                             f                                f
# 2165                             f                                f
# 2173                             f                                f
# 2176                             f                                f
# 2201                             f                                f
# 2218                             f                                f
# ...                            ...                              ...
# 4374                             f                                f
# 4394                             f                                f
# 4414                             f                                f
# 4470                             f                                f
# 4492                             f                                f
# 4563                             f                                f
# 4608                             f                                f
# 4724                             f                                f
# 4745                             f                                f
# 4746                             f                                f
# 4756                             f                                f
# 4796                             f                                f
# 4818                             f                                f
# 4828                             f                                f
# 4887                             f                                f
# 4895                             f                                f
# 4901                             f                                f
# 4989                             f                                f
# 4999                             f                                f
# 5012                             f                                f
# 5023                             f                                f
# 5036                             f                                f
# 5077                             f                                f
# 5128                             f                                f
# 5169                             f                                f
# 5187                             f                                f
# 5239                             f                                f
# 5300                             f                                f
# 5309                             f                                f
# 5314                             f                                f
#
#       calculated_host_listings_count reviews_per_month
# 49                                 1              0.60
# 286                                1              0.22
# 305                                1              5.66
# 447                                3              0.36
# 460                                1              0.02
# 542                                1              0.06
# 643                                1              1.11
# 690                                3               NaN
# 691                                3              0.47
# 921                                1              0.24
# 940                                1              0.14
# 1086                               1              0.53
# 1169                               1              1.51
# 1295                               1              1.12
# 1312                               1              0.04
# 1503                               1               NaN
# 1521                               1              1.26
# 1524                               1              2.08
# 1544                               1              0.59
# 1573                               1              4.55
# 1681                               1              0.63
# 1874                               2              1.65
# 1878                               2               NaN
# 2015                               1              0.26
# 2018                               1              1.14
# 2165                               1              6.89
# 2173                               2              0.81
# 2176                               2              0.56
# 2201                               1              3.84
# 2218                               1              0.36
# ...                              ...               ...
# 4374                               1              2.54
# 4394                               1              0.29
# 4414                               1              3.49
# 4470                               1              3.52
# 4492                               1              7.89
# 4563                               2             12.95
# 4608                               2              6.79
# 4724                               1              0.32
# 4745                               2              4.67
# 4746                               1              0.45
# 4756                               1              1.43
# 4796                               1              2.11
# 4818                               1               NaN
# 4828                               1              6.55
# 4887                               1              3.67
# 4895                               1              5.88
# 4901                               2              3.75
# 4989                               2              4.00
# 4999                               2              4.68
# 5012                               1               NaN
# 5023                               3              7.23
# 5036                               3             11.05
# 5077                               3              3.33
# 5128                               1              3.00
# 5169                               1              2.00
# 5187                               1              7.00
# 5239                               1               NaN
# 5300                               3               NaN
# 5309                               3               NaN
# 5314                               3               NaN
#
# [113 rows x 50 columns]

# %%
airbnb.

# %%
zipcodes = ['97034', '97035']
airbnb.loc[airbnb['zipcodes']==zipcodes]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zipcodes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-1ea29a2a2621> in <module>()
#       1 zipcodes = ['97034', '97035']
# ----> 2 airbnb.loc[airbnb['zipcodes']==zipcodes]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zipcodes'

# %% [markdown]
# ## To Do
# - start looking for links between variables and price of stay/night. unfortunately, most data does not have sq footage so will have to take entire price and compare, despite different size apts/homes.
# - analyze data above
# - find out where all the NaNs are in the columns to give a total count of 14 post-dropna. see if we can change the values to zero
# - once there seems to be some interesting parallels.. try doing a t test between the best and worst variables (ex. neighbors), or should I wait and see if normal distribution? Maybe i'll have to do mann-whitney instead.

# %% [markdown]
# ### Apartmentlist.com data
# - I think this data is not so good. The Portland, OR locations are mislabeled in their states. But, the prices extend into 2018, so it's up to date
# - this is also averages, but it's per # of bedrooms in a home, rather than sqft as Zillow
#
# -  could consider looking at monthly rental prices in the area as well, to see if airbnb is more profitable than renting, data here: https://www.apartmentlist.com/rentonomics/rental-price-data/

# %% [markdown]
# rent = pd.read_csv('Apartment-Rent-Data-City_2018-10.csv')

# %% [markdown]
# portland_rent = rent[rent['Location'] == 'Portland, OR']
# portland_rent.describe()

# %% [markdown]
# portland_rent

# %% [markdown]
# ### Zillow rent data
# - Data probably much more reliable, uses their Rent Zestimates algorithms to track the rental data, includes locations that aren't currently listed. Only extends to 2017 data
# - only shows overall average per neighborhood
# - price per sq ftage.. how will i compare to the airbnb data?

# %%
zillow = pd.read_csv('zillow-pricepersqft.csv')

# %%
zillow_OR = zillow[(zillow['Metro']=='Portland') & (zillow['State']=='OR')]
zillow_OR.head()
# Out:
#      City Code       City     Metro      County State  Population Rank  \
# 29       13373   Portland  Portland   Multnomah    OR               30
# 322      30381  Beaverton  Portland  Washington    OR              323
# 380      11914  Hillsboro  Portland  Washington    OR              381
# 578      24967    Gresham  Portland   Multnomah    OR              579
# 860      30177      Aloha  Portland  Washington    OR              861
#
#      November 2010  December 2010  January 2011  February 2011  March 2011  \
# 29           1.020          1.018         1.018          1.022       1.028
# 322          0.838          0.846         0.848          0.844       0.844
# 380          0.798          0.810         0.814          0.814       0.812
# 578          0.848          0.838         0.830          0.824       0.822
# 860          0.850          0.860         0.860          0.854       0.846
#
#      April 2011  May 2011  June 2011  July 2011      ...       November 2015  \
# 29        1.032     1.036      1.038      1.042      ...               1.434
# 322       0.844     0.846      0.852      0.856      ...               1.092
# 380       0.812     0.812      0.816      0.816      ...               1.024
# 578       0.818     0.816      0.814      0.818      ...               1.080
# 860       0.842     0.842      0.846      0.848      ...               1.076
#
#      December 2015  January 2016  February 2016  March 2016  April 2016  \
# 29           1.444         1.456          1.464       1.476       1.486
# 322          1.098         1.106          1.112       1.124       1.134
# 380          1.028         1.036          1.044       1.054       1.066
# 578          1.082         1.088          1.098       1.110       1.120
# 860          1.082         1.090          1.098       1.112       1.124
#
#      May 2016  June 2016  July 2016  August 2016  September 2016  \
# 29      1.498      1.506      1.510        1.512           1.516
# 322     1.146      1.156      1.162        1.168           1.174
# 380     1.076      1.086      1.090        1.092           1.096
# 578     1.130      1.138      1.142        1.144           1.146
# 860     1.136      1.144      1.148        1.152           1.160
#
#      October 2016  November 2016  December 2016  January 2017
# 29          1.520          1.524          1.524         1.520
# 322         1.178          1.182          1.182         1.178
# 380         1.100          1.102          1.102         1.100
# 578         1.152          1.154          1.158         1.160
# 860         1.168          1.176          1.176         1.172
#
# [5 rows x 81 columns]

# %%
zillow_OR
