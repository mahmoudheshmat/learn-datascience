# %% [markdown]
# As a capstone to this fundamentals course, prepare an Analytic Report and Research Proposal on a dataset of your choosing. Your Report should accomplish these three goals:
#
#     Describe your dataset. Describe and explore your dataset in the initial section of your Report. What does your data contain and what is its background? Where does it come from? Why is it interesting or significant? Conduct summary statistics and produce visualizations for the particular variables from the dataset that you will use.
#
#     Ask and answer analytic questions. Ask three analytic questions and answer each one with a combination of statistics and visualizations. These analytic questions can focus on individuals behaviors or comparisons of the population.
#
#     Propose further research. Lastly, make a proposal for a realistic future research project on this dataset that would use some data science techniques you'd like to learn in the bootcamp. Just like your earlier questions, your research proposal should present one or more clear questions. Then you should describe the techniques you would apply in order to arrive at an answer.
#
# Report guidelines
#
# Keep these guidelines in mind as you draft your Report:
#
#     Length. Your Report should be three to five pages long with visualizations. Short and clear is better than long and opaque.
#     Structure. Pay attention to the narrative structure of your Report. Each section should flow into the next and make a logical, readable text. Don't simply create a list of bullet points or present code without explanation.
#
#
#
#     http://insideairbnb.com/get-the-data.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
pd.options.display.max_columns=30

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
#plt.rcParams({'font.size': 22})

# %% [markdown]
# ## Describe the datasets

# %% [markdown]
# theme: report for someone wanting to build a side income renting out airbnb in Portland, OR
# -  could consider looking at monthly rental prices in the area as well, to see if airbnb is more profitable than renting, data here: https://www.apartmentlist.com/rentonomics/rental-price-data/
# problem: not finding data with resolution better than just the city of Portland. can i even use this source? they have location as portland OR yet list as NY state, can I trust?
# 1. how much can one expect to make renting vs airbnb?
# 2. how much does it cost to pay off an apartment/house, how long would it take to pay off property with airbnb rentals?
# 3. links between: neighborhood and price (are room types confounding?), number of reviews//reviews per month an price, room type and price, availability over the course of a year and price. aka how can one maximize their profits on airbnb?

# %% [markdown]
# ## AirBnB data

# %%
full_OR_airbnb = pd.read_csv('listings.csv.gz', compression='gzip')

# %%
full_OR_airbnb.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
full_OR_airbnb = full_OR_airbnb.drop(columns=['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate', 'host_total_listings_count', 'neighbourhood_group_cleansed', 
                                              'requires_license', 'license', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 
                                              'calendar_last_scraped', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'street', 
                                              'host_verifications', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'listing_url', 'scrape_id',
                                              'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
                                              'house_rules', 'picture_url', 'host_id', 'host_url'])
full_OR_airbnb.describe()
# Out:
#                  id  host_listings_count  accommodates    bathrooms  \
# count  5.317000e+03          5312.000000   5317.000000  5314.000000
# mean   1.531575e+07            12.256589      3.435960     1.230335
# std    8.481055e+06           114.287981      1.898449     0.510583
# min    7.893000e+03             0.000000      1.000000     0.000000
# 25%    7.959145e+06             1.000000      2.000000     1.000000
# 50%    1.625721e+07             1.000000      3.000000     1.000000
# 75%    2.188217e+07             2.000000      4.000000     1.000000
# max    2.986167e+07          1305.000000     24.000000     5.000000
#
#           bedrooms         beds  square_feet  guests_included  minimum_nights  \
# count  5315.000000  5316.000000    61.000000      5317.000000     5317.000000
# mean      1.359172     1.869451   686.327869         1.811360        4.221930
# std       0.901567     1.230026   623.922798         1.292145       10.049577
# min       0.000000     0.000000     0.000000         1.000000        1.000000
# 25%       1.000000     1.000000   150.000000         1.000000        1.000000
# 50%       1.000000     2.000000   550.000000         1.000000        2.000000
# 75%       2.000000     2.000000  1000.000000         2.000000        2.000000
# max       8.000000    16.000000  2500.000000        15.000000      222.000000
#
#        maximum_nights  number_of_reviews  review_scores_rating  \
# count     5317.000000        5317.000000           4846.000000
# mean       489.343051          60.934173             96.931077
# std        534.905799          81.961679              4.410958
# min          1.000000           0.000000             20.000000
# 25%         21.000000           6.000000             96.000000
# 50%         90.000000          29.000000             98.000000
# 75%       1125.000000          84.000000            100.000000
# max       5000.000000         865.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4844.000000                4843.000000
# mean                 9.880058                   9.784844
# std                  0.426587                   0.548327
# min                  2.000000                   2.000000
# 25%                 10.000000                  10.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4841.000000                  4842.000000
# mean                9.940921                     9.932879
# std                 0.302573                     0.341687
# min                 5.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             4841.000000          4841.000000
# mean                 9.790126             9.739103
# std                  0.477763             0.551386
# min                  4.000000             2.000000
# 25%                 10.000000            10.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     5317.000000        4877.000000
# mean                         2.123190           3.013443
# std                          4.193996           2.920180
# min                          1.000000           0.010000
# 25%                          1.000000           0.780000
# 50%                          1.000000           2.380000
# 75%                          2.000000           4.450000
# max                         41.000000          58.160000

# %%
full_OR_airbnb.head()
# Out:
#       id      host_name  host_since  host_response_time host_response_rate  \
# 0   7893          Jesse  2009-06-14                 NaN                NaN
# 1  12899  Ali And David  2009-10-29                 NaN                NaN
# 2  16688         Ashish  2009-12-21      within an hour               100%
# 3  25200         Garden  2010-04-05  within a few hours               100%
# 4  26203         Garden  2010-04-05  within a few hours               100%
#
#   host_is_superhost  host_listings_count host_has_profile_pic  \
# 0                 f                  1.0                    t
# 1                 t                  1.0                    t
# 2                 t                  1.0                    t
# 3                 f                  7.0                    t
# 4                 f                  7.0                    t
#
#   host_identity_verified neighbourhood neighbourhood_cleansed      city state  \
# 0                      f      Piedmont               Piedmont  Portland    OR
# 1                      t     Concordia              Concordia  Portland    OR
# 2                      f         Pearl                  Pearl  Portland    OR
# 3                      t      Humboldt               Humboldt  Portland    OR
# 4                      t      Humboldt               Humboldt  Portland    OR
#
#   zipcode property_type        ...        review_scores_rating  \
# 0   97217         House        ...                       100.0
# 1   97211   Guest suite        ...                        98.0
# 2   97209         House        ...                        97.0
# 3   97217         House        ...                        93.0
# 4   97217         House        ...                        92.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                     9.0                        9.0                   10.0
# 4                     9.0                       10.0                    9.0
#
#    review_scores_communication review_scores_location review_scores_value  \
# 0                         10.0                   10.0                10.0
# 1                         10.0                   10.0                10.0
# 2                         10.0                   10.0                 9.0
# 3                         10.0                   10.0                 9.0
# 4                         10.0                   10.0                 9.0
#
#                   jurisdiction_names instant_bookable  \
# 0  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4  {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f                     moderate
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count reviews_per_month
# 0                               1              0.02
# 1                               1              4.67
# 2                               1              2.37
# 3                               6              0.33
# 4                               6              0.27
#
# [5 rows x 50 columns]

# %%
full_OR_airbnb.host_response_time.unique()
# Out:
# array([nan, 'within an hour', 'within a few hours', 'within a day',
#        'a few days or more'], dtype=object)

# %%
full_OR_airbnb.describe()
# Out:
#                  id  host_listings_count  accommodates    bathrooms  \
# count  5.317000e+03          5312.000000   5317.000000  5314.000000
# mean   1.531575e+07            12.256589      3.435960     1.230335
# std    8.481055e+06           114.287981      1.898449     0.510583
# min    7.893000e+03             0.000000      1.000000     0.000000
# 25%    7.959145e+06             1.000000      2.000000     1.000000
# 50%    1.625721e+07             1.000000      3.000000     1.000000
# 75%    2.188217e+07             2.000000      4.000000     1.000000
# max    2.986167e+07          1305.000000     24.000000     5.000000
#
#           bedrooms         beds  square_feet  guests_included  minimum_nights  \
# count  5315.000000  5316.000000    61.000000      5317.000000     5317.000000
# mean      1.359172     1.869451   686.327869         1.811360        4.221930
# std       0.901567     1.230026   623.922798         1.292145       10.049577
# min       0.000000     0.000000     0.000000         1.000000        1.000000
# 25%       1.000000     1.000000   150.000000         1.000000        1.000000
# 50%       1.000000     2.000000   550.000000         1.000000        2.000000
# 75%       2.000000     2.000000  1000.000000         2.000000        2.000000
# max       8.000000    16.000000  2500.000000        15.000000      222.000000
#
#        maximum_nights  number_of_reviews  review_scores_rating  \
# count     5317.000000        5317.000000           4846.000000
# mean       489.343051          60.934173             96.931077
# std        534.905799          81.961679              4.410958
# min          1.000000           0.000000             20.000000
# 25%         21.000000           6.000000             96.000000
# 50%         90.000000          29.000000             98.000000
# 75%       1125.000000          84.000000            100.000000
# max       5000.000000         865.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4844.000000                4843.000000
# mean                 9.880058                   9.784844
# std                  0.426587                   0.548327
# min                  2.000000                   2.000000
# 25%                 10.000000                  10.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4841.000000                  4842.000000
# mean                9.940921                     9.932879
# std                 0.302573                     0.341687
# min                 5.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             4841.000000          4841.000000
# mean                 9.790126             9.739103
# std                  0.477763             0.551386
# min                  4.000000             2.000000
# 25%                 10.000000            10.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     5317.000000        4877.000000
# mean                         2.123190           3.013443
# std                          4.193996           2.920180
# min                          1.000000           0.010000
# 25%                          1.000000           0.780000
# 50%                          1.000000           2.380000
# 75%                          2.000000           4.450000
# max                         41.000000          58.160000

# %%
airbnb = full_OR_airbnb.drop(columns=['square_feet', 'weekly_price', 'monthly_price']) 
        # dropped because only 61 of 5000 listings have this info
        # only using price/night, not considering weekly/monthly discounts

# %%
airbnb.loc[airbnb['beds']==6]
# Out:
#             id          host_name  host_since  host_response_time  \
# 17       67036               Will  2010-12-29      within an hour
# 51      205616               Jody  2011-08-23  within a few hours
# 249    1135861             Joelle  2010-08-26      within an hour
# 263    1212772  Bryan And Jessica  2013-04-21      within an hour
# 384    1815429            Kathryn  2013-06-18                 NaN
# 535    2975748                Max  2014-05-06                 NaN
# 579    3290914               Dana  2013-01-28      within an hour
# 710    4121134           Jennifer  2013-09-01                 NaN
# 1116   6555772             Kristy  2015-05-26                 NaN
# 1286   7699084              Sheri  2015-07-29  within a few hours
# 1361   8118223              Laura  2011-08-26      within an hour
# 1418   8498216                Mel  2015-02-18      within an hour
# 1796  11239664          Benedicta  2013-06-23                 NaN
# 1913  12104156             Stuart  2015-10-07                 NaN
# 1969  12608430            Tiffany  2016-04-18      within an hour
# 1992  12760040            Tiffany  2016-04-18      within an hour
# 1993  12760406            Tiffany  2016-04-18      within an hour
# 2454  15146074            Tiffany  2016-04-18      within an hour
# 2584  15900501            Heather  2016-11-09      within an hour
# 2706  16572315  Jordann And Brian  2011-09-04      within an hour
# 2728  16706708           Virginia  2013-03-18                 NaN
# 2802  17125533             Daniel  2014-12-04                 NaN
# 2963  18076979               Anna  2013-02-20                 NaN
# 3019  18374143                Sue  2015-06-27                 NaN
# 3361  19812948           Michelle  2012-04-26      within an hour
# 3392  19952673            Lindsay  2014-08-22                 NaN
# 3471  20214630            Jacquie  2015-08-09      within an hour
# 3509  20328968                Sam  2016-12-16  within a few hours
# 3815  21381605           AnnMarie  2015-11-13                 NaN
# 3872  21579586            Colleen  2017-02-02                 NaN
# 3954  21815569                Amy  2012-08-02      within an hour
# 3955  21815931                Amy  2012-08-02      within an hour
# 4155  22700608             Carrie  2015-01-25                 NaN
# 4276  23450314              Susan  2018-02-22      within an hour
# 4417  24311797              Peter  2015-12-19      within an hour
# 4427  24358125               Nick  2015-08-21      within an hour
# 4475  24657532                 Kc  2018-04-25      within an hour
# 4561  25132066     Jamie And Dave  2013-10-30  within a few hours
# 4589  25266268              Karen  2013-03-04                 NaN
# 4692  25935157       Jim And Jenn  2016-01-15      within an hour
# 4953  27398802              Sandi  2015-06-07      within an hour
# 4998  27654782             Jeanne  2016-12-22      within an hour
# 5055  28078692             Edmund  2015-03-29      within an hour
# 5081  28252091             Jeanne  2016-12-22      within an hour
#
#      host_response_rate host_is_superhost  host_listings_count  \
# 17                 100%                 f                  1.0
# 51                 100%                 f                  7.0
# 249                100%                 f                  1.0
# 263                100%                 f                  3.0
# 384                 NaN                 t                  4.0
# 535                 NaN                 f                  1.0
# 579                100%                 t                  2.0
# 710                 NaN                 f                  1.0
# 1116                NaN                 t                  2.0
# 1286               100%                 f                  1.0
# 1361               100%                 t                  1.0
# 1418               100%                 f                  9.0
# 1796                NaN                 t                  1.0
# 1913                NaN                 f                  9.0
# 1969               100%                 t                  4.0
# 1992               100%                 t                  4.0
# 1993               100%                 t                  4.0
# 2454               100%                 t                  4.0
# 2584               100%                 f                  2.0
# 2706               100%                 t                  1.0
# 2728                NaN                 f                  1.0
# 2802                NaN                 t                  1.0
# 2963                NaN                 t                  1.0
# 3019                NaN                 f                  1.0
# 3361               100%                 t                  1.0
# 3392                NaN                 f                  1.0
# 3471                83%                 f                  1.0
# 3509               100%                 f                  1.0
# 3815                NaN                 f                  1.0
# 3872                NaN                 t                  1.0
# 3954               100%                 t                 21.0
# 3955               100%                 t                 21.0
# 4155                NaN                 f                  3.0
# 4276               100%                 f                  2.0
# 4417               100%                 t                  1.0
# 4427               100%                 t                  1.0
# 4475               100%                 f                  2.0
# 4561               100%                 f                  1.0
# 4589                NaN                 f                  1.0
# 4692               100%                 t                  1.0
# 4953               100%                 t                  7.0
# 4998               100%                 t                  5.0
# 5055               100%                 f                  1.0
# 5081               100%                 t                  5.0
#
#      host_has_profile_pic host_identity_verified        neighbourhood  \
# 17                      t                      t                  NaN
# 51                      t                      t            Irvington
# 249                     t                      f             Overlook
# 263                     t                      t            Concordia
# 384                     t                      t                  NaN
# 535                     t                      t            Sunnyside
# 579                     t                      t            St. Johns
# 710                     t                      t             Richmond
# 1116                    t                      t        Foster-Powell
# 1286                    t                      f            Maplewood
# 1361                    t                      t             Overlook
# 1418                    t                      f          Forest Park
# 1796                    t                      f            Woodstock
# 1913                    t                      t  Powellhurst-Gilbert
# 1969                    t                      f       Lloyd District
# 1992                    t                      f       Lloyd District
# 1993                    t                      f       Lloyd District
# 2454                    t                      f       Lloyd District
# 2584                    t                      f              Buckman
# 2706                    t                      t           Bridlemile
# 2728                    t                      t      Pleasant Valley
# 2802                    t                      f                  NaN
# 2963                    t                      t                  NaN
# 3019                    t                      t            Hillsdale
# 3361                    t                      t            Sunnyside
# 3392                    t                      t              Alameda
# 3471                    t                      t                  NaN
# 3509                    t                      f   Northwest District
# 3815                    t                      f       Rose City Park
# 3872                    t                      f                 King
# 3954                    t                      f            Homestead
# 3955                    t                      f            Homestead
# 4155                    t                      t             Richmond
# 4276                    t                      f                Kerns
# 4417                    t                      t                Cully
# 4427                    t                      f           Bridlemile
# 4475                    t                      f            Multnomah
# 4561                    t                      f              Markham
# 4589                    t                      t    Sellwood-Moreland
# 4692                    t                      t   Northwest District
# 4953                    t                      t             Hayhurst
# 4998                    t                      t            Irvington
# 5055                    t                      t               Kenton
# 5081                    t                      t            Irvington
#
#                     neighbourhood_cleansed      city state zipcode  \
# 17                        Sullivan's Gulch  Portland    OR   97232
# 51                               Irvington  Portland    OR   97212
# 249                               Overlook  Portland    OR   97217
# 263                              Concordia  Portland    OR   97211
# 384                                  Sabin  Portland    OR   97211
# 535                              Sunnyside  Portland    OR   97214
# 579                              St. Johns  Portland    OR   97203
# 710                               Richmond  Portland    OR   97214
# 1116                         Foster-Powell  Portland    OR   97206
# 1286                             Maplewood  Portland    OR   97219
# 1361                              Overlook  Portland    OR   97227
# 1418                           Forest Park  Portland    OR   97210
# 1796                             Woodstock  Portland    OR   97202
# 1913                   Powellhurst-Gilbert  Portland    OR   97236
# 1969                        Lloyd District  Portland    OR   97232
# 1992                        Lloyd District  Portland    OR   97232
# 1993                        Lloyd District  Portland    OR   97232
# 2454                        Lloyd District  Portland    OR   97232
# 2584                               Buckman  Portland    OR   97214
# 2706                            Bridlemile  Portland    OR   97225
# 2728                       Pleasant Valley  Portland    OR   97236
# 2802                        South Portland  Portland    OR   97201
# 2963                           North Tabor  Portland    OR   97215
# 3019                             Hillsdale  Portland    OR   97239
# 3361                             Sunnyside  Portland    OR   97214
# 3392                               Alameda  Portland    OR   97212
# 3471                               Markham  Portland    OR   97219
# 3509                    Northwest District  Portland    OR   97209
# 3815                        Rose City Park  Portland    OR   97213
# 3872                                  King  Portland    OR   97212
# 3954                             Homestead  Portland    OR   97239
# 3955                             Homestead  Portland    OR   97239
# 4155                              Richmond  Portland    OR   97202
# 4276                                 Kerns  Portland    OR   97214
# 4417                                 Cully  Portland    OR   97218
# 4427                            Bridlemile  Portland    OR   97221
# 4475                             Multnomah  Portland    OR   97219
# 4561                               Markham  Portland    OR   97219
# 4589  Sellwood-Moreland Improvement League  Portland    OR   97202
# 4692                    Northwest District  Portland    OR   97210
# 4953                              Hayhurst  Portland    OR   97221
# 4998                             Irvington  Portland    OR   97212
# 5055                                Kenton  Portland    OR   97217
# 5081                             Irvington  Portland    OR   97212
#
#      property_type        ...         review_scores_rating  \
# 17           House        ...                         99.0
# 51           House        ...                         92.0
# 249     Guesthouse        ...                         77.0
# 263          House        ...                         98.0
# 384          House        ...                         87.0
# 535          House        ...                         99.0
# 579          House        ...                         97.0
# 710          House        ...                        100.0
# 1116         House        ...                        100.0
# 1286         House        ...                          NaN
# 1361         House        ...                         98.0
# 1418         House        ...                         96.0
# 1796         House        ...                         97.0
# 1913         House        ...                         93.0
# 1969     Apartment        ...                         95.0
# 1992     Apartment        ...                         92.0
# 1993     Apartment        ...                         97.0
# 2454     Apartment        ...                         97.0
# 2584         House        ...                         99.0
# 2706         House        ...                         99.0
# 2728         House        ...                          NaN
# 2802         House        ...                         99.0
# 2963         House        ...                         99.0
# 3019         House        ...                          NaN
# 3361         House        ...                         98.0
# 3392         House        ...                         90.0
# 3471         House        ...                        100.0
# 3509         House        ...                         98.0
# 3815         House        ...                         80.0
# 3872         House        ...                         99.0
# 3954         House        ...                          NaN
# 3955         House        ...                          NaN
# 4155     Townhouse        ...                        100.0
# 4276         House        ...                         96.0
# 4417         House        ...                         98.0
# 4427         House        ...                        100.0
# 4475   Condominium        ...                         98.0
# 4561         House        ...                        100.0
# 4589         House        ...                        100.0
# 4692         House        ...                         99.0
# 4953         House        ...                          NaN
# 4998         House        ...                        100.0
# 5055         House        ...                        100.0
# 5081         House        ...                        100.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 17                      10.0                       10.0
# 51                       9.0                        9.0
# 249                      8.0                        8.0
# 263                     10.0                       10.0
# 384                     10.0                        9.0
# 535                     10.0                        9.0
# 579                     10.0                       10.0
# 710                     10.0                       10.0
# 1116                    10.0                       10.0
# 1286                     NaN                        NaN
# 1361                    10.0                       10.0
# 1418                     9.0                        9.0
# 1796                    10.0                       10.0
# 1913                     9.0                        9.0
# 1969                    10.0                       10.0
# 1992                    10.0                       10.0
# 1993                    10.0                       10.0
# 2454                    10.0                       10.0
# 2584                    10.0                       10.0
# 2706                    10.0                       10.0
# 2728                     NaN                        NaN
# 2802                    10.0                       10.0
# 2963                    10.0                       10.0
# 3019                     NaN                        NaN
# 3361                    10.0                       10.0
# 3392                    10.0                        9.0
# 3471                    10.0                       10.0
# 3509                    10.0                       10.0
# 3815                     9.0                        8.0
# 3872                    10.0                       10.0
# 3954                     NaN                        NaN
# 3955                     NaN                        NaN
# 4155                    10.0                       10.0
# 4276                    10.0                       10.0
# 4417                    10.0                       10.0
# 4427                    10.0                       10.0
# 4475                    10.0                       10.0
# 4561                    10.0                       10.0
# 4589                    10.0                       10.0
# 4692                    10.0                       10.0
# 4953                     NaN                        NaN
# 4998                    10.0                       10.0
# 5055                    10.0                       10.0
# 5081                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 17                     10.0                         10.0
# 51                     10.0                         10.0
# 249                     9.0                          8.0
# 263                    10.0                         10.0
# 384                    10.0                         10.0
# 535                    10.0                         10.0
# 579                    10.0                         10.0
# 710                    10.0                         10.0
# 1116                   10.0                         10.0
# 1286                    NaN                          NaN
# 1361                   10.0                         10.0
# 1418                   10.0                         10.0
# 1796                   10.0                         10.0
# 1913                   10.0                         10.0
# 1969                   10.0                         10.0
# 1992                   10.0                         10.0
# 1993                   10.0                         10.0
# 2454                   10.0                         10.0
# 2584                   10.0                         10.0
# 2706                   10.0                         10.0
# 2728                    NaN                          NaN
# 2802                   10.0                         10.0
# 2963                   10.0                         10.0
# 3019                    NaN                          NaN
# 3361                   10.0                         10.0
# 3392                   10.0                         10.0
# 3471                   10.0                         10.0
# 3509                   10.0                         10.0
# 3815                    8.0                          7.0
# 3872                   10.0                         10.0
# 3954                    NaN                          NaN
# 3955                    NaN                          NaN
# 4155                   10.0                         10.0
# 4276                   10.0                         10.0
# 4417                   10.0                         10.0
# 4427                   10.0                         10.0
# 4475                   10.0                         10.0
# 4561                   10.0                         10.0
# 4589                   10.0                         10.0
# 4692                   10.0                         10.0
# 4953                    NaN                          NaN
# 4998                   10.0                         10.0
# 5055                   10.0                         10.0
# 5081                   10.0                         10.0
#
#      review_scores_location review_scores_value  \
# 17                     10.0                10.0
# 51                     10.0                 9.0
# 249                     9.0                 8.0
# 263                    10.0                10.0
# 384                    10.0                 9.0
# 535                    10.0                10.0
# 579                    10.0                10.0
# 710                    10.0                10.0
# 1116                    9.0                10.0
# 1286                    NaN                 NaN
# 1361                   10.0                10.0
# 1418                   10.0                 9.0
# 1796                   10.0                 9.0
# 1913                    9.0                 9.0
# 1969                    9.0                10.0
# 1992                    9.0                 9.0
# 1993                    9.0                 9.0
# 2454                    9.0                 9.0
# 2584                   10.0                 9.0
# 2706                   10.0                10.0
# 2728                    NaN                 NaN
# 2802                    9.0                10.0
# 2963                   10.0                10.0
# 3019                    NaN                 NaN
# 3361                   10.0                10.0
# 3392                    9.0                 9.0
# 3471                   10.0                10.0
# 3509                   10.0                10.0
# 3815                   10.0                 9.0
# 3872                   10.0                 9.0
# 3954                    NaN                 NaN
# 3955                    NaN                 NaN
# 4155                   10.0                10.0
# 4276                   10.0                 9.0
# 4417                    9.0                10.0
# 4427                   10.0                10.0
# 4475                   10.0                10.0
# 4561                   10.0                10.0
# 4589                   10.0                10.0
# 4692                   10.0                10.0
# 4953                    NaN                 NaN
# 4998                   10.0                10.0
# 5055                   10.0                10.0
# 5081                   10.0                 8.0
#
#                        jurisdiction_names instant_bookable  \
# 17      {OREGON," MULTNOMAH"," PORTLAND"}                f
# 51      {OREGON," MULTNOMAH"," PORTLAND"}                f
# 249     {OREGON," MULTNOMAH"," PORTLAND"}                t
# 263     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 384     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 535     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 579     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 710     {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1116    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1286    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1361    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1418                {OREGON," MULTNOMAH"}                f
# 1796    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1913    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1969    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1992    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1993    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 2454    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 2584    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2706  {OREGON," Washington County"," OR"}                f
# 2728    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2802    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 2963    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3019    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3361    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3392    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3471    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3509    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3815    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3872    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3954    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3955    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4155    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4276    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4417    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4427    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4475    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4561    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4589    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4692    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4953    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4998    {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5055    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5081    {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#      is_business_travel_ready          cancellation_policy  \
# 17                          f  strict_14_with_grace_period
# 51                          f  strict_14_with_grace_period
# 249                         f  strict_14_with_grace_period
# 263                         f  strict_14_with_grace_period
# 384                         f  strict_14_with_grace_period
# 535                         f                     moderate
# 579                         f  strict_14_with_grace_period
# 710                         f  strict_14_with_grace_period
# 1116                        f  strict_14_with_grace_period
# 1286                        f  strict_14_with_grace_period
# 1361                        f  strict_14_with_grace_period
# 1418                        f  strict_14_with_grace_period
# 1796                        f                     moderate
# 1913                        f                     moderate
# 1969                        f                     moderate
# 1992                        f                     moderate
# 1993                        f                     moderate
# 2454                        f                     moderate
# 2584                        f  strict_14_with_grace_period
# 2706                        f                     moderate
# 2728                        f                     moderate
# 2802                        f                     moderate
# 2963                        f  strict_14_with_grace_period
# 3019                        f  strict_14_with_grace_period
# 3361                        f  strict_14_with_grace_period
# 3392                        f                     flexible
# 3471                        f                     moderate
# 3509                        f  strict_14_with_grace_period
# 3815                        f  strict_14_with_grace_period
# 3872                        f  strict_14_with_grace_period
# 3954                        f  strict_14_with_grace_period
# 3955                        f                     flexible
# 4155                        f  strict_14_with_grace_period
# 4276                        f  strict_14_with_grace_period
# 4417                        f  strict_14_with_grace_period
# 4427                        f  strict_14_with_grace_period
# 4475                        f                     moderate
# 4561                        f  strict_14_with_grace_period
# 4589                        f                     moderate
# 4692                        f  strict_14_with_grace_period
# 4953                        f                     flexible
# 4998                        f                     moderate
# 5055                        f                     flexible
# 5081                        f                     flexible
#
#      require_guest_profile_picture  require_guest_phone_verification  \
# 17                               f                                 t
# 51                               f                                 f
# 249                              f                                 f
# 263                              t                                 t
# 384                              t                                 t
# 535                              f                                 f
# 579                              f                                 f
# 710                              f                                 f
# 1116                             f                                 f
# 1286                             f                                 f
# 1361                             f                                 f
# 1418                             f                                 f
# 1796                             f                                 f
# 1913                             f                                 f
# 1969                             f                                 f
# 1992                             f                                 f
# 1993                             f                                 f
# 2454                             f                                 f
# 2584                             f                                 f
# 2706                             f                                 f
# 2728                             f                                 f
# 2802                             f                                 f
# 2963                             f                                 f
# 3019                             f                                 f
# 3361                             f                                 f
# 3392                             f                                 f
# 3471                             f                                 f
# 3509                             f                                 f
# 3815                             f                                 f
# 3872                             f                                 f
# 3954                             f                                 f
# 3955                             f                                 f
# 4155                             f                                 f
# 4276                             f                                 f
# 4417                             f                                 f
# 4427                             f                                 f
# 4475                             f                                 f
# 4561                             f                                 f
# 4589                             f                                 f
# 4692                             f                                 f
# 4953                             f                                 f
# 4998                             f                                 f
# 5055                             f                                 f
# 5081                             f                                 f
#
#       calculated_host_listings_count  reviews_per_month
# 17                                 1               0.22
# 51                                 7               1.37
# 249                                1               0.64
# 263                                1               2.52
# 384                                4               0.13
# 535                                1               0.04
# 579                                1               2.96
# 710                                1               0.12
# 1116                               1               1.42
# 1286                               1                NaN
# 1361                               1               3.80
# 1418                               7               3.37
# 1796                               1               0.75
# 1913                               9               2.43
# 1969                               4               3.91
# 1992                               4               2.66
# 1993                               4               2.74
# 2454                               4               2.15
# 2584                               2               1.92
# 2706                               1               8.88
# 2728                               1               0.12
# 2802                               1               1.40
# 2963                               1               1.26
# 3019                               1                NaN
# 3361                               1               2.97
# 3392                               1               0.27
# 3471                               1               0.49
# 3509                               1               5.60
# 3815                               1               0.71
# 3872                               1               4.47
# 3954                              15                NaN
# 3955                              15                NaN
# 4155                               3               0.34
# 4276                               2               5.51
# 4417                               1               4.74
# 4427                               1               3.29
# 4475                               1               2.18
# 4561                               1               1.81
# 4589                               1               1.13
# 4692                               1               5.36
# 4953                               7                NaN
# 4998                               4               0.94
# 5055                               1               2.78
# 5081                               4               1.00
#
# [44 rows x 47 columns]

# %%
airbnb.neighbourhood_cleansed.value_counts().plot(kind="bar")
plt.xlabel('Neighbourhood')
plt.ylabel('Number of listings')
plt.title('AirBnB listings per neighborhood')
plt.show()

# %% [markdown]
# <b>Note:</b> Lots of different neighborhood classifications. Might want to combine some of these for it to be of use, or use jurisdiction

# %%
airbnb.jurisdiction_names.value_counts().plot(kind='bar')

# %% [markdown]
# <b>Note:</b> Okay jurisdiction won't be useful either - almost everything is in Multnomah county

# %%
airbnb.zipcode.value_counts().plot(kind='bar')

# %% [markdown]
# <b>Note:</b> These have a more digestible amount of categories. I could even remove the last 10 or so because there isn't enough airbnb love there. If going by zip code, it might be difficult to compare to apartmentlist and zillow that combines by city name

# %%
airbnb.bed_type.value_counts()
# Out:
# Real Bed         5214
# Futon              57
# Pull-out Sofa      27
# Airbed             10
# Couch               9
# Name: bed_type, dtype: int64

# %% [markdown]
# ## To Do
# - start looking for links between variables and price of stay/night. unfortunately, most data does not have sq footage so will have to take entire price and compare, despite different size apts/homes.
# - analyze data above
# - find out where all the NaNs are in the columns to give a total count of 14 post-dropna. see if we can change the values to zero
# - once there seems to be some interesting parallels.. try doing a t test between the best and worst variables (ex. neighbors), or should I wait and see if normal distribution? Maybe i'll have to do mann-whitney instead.

# %% [markdown]
# ### Apartmentlist.com data
# - I think this data is not so good. The Portland, OR locations are mislabeled in their states. But, the prices extend into 2018, so it's up to date
# - this is also averages, but it's per # of bedrooms in a home, rather than sqft as Zillow

# %% [markdown]
# rent = pd.read_csv('Apartment-Rent-Data-City_2018-10.csv')

# %% [markdown]
# portland_rent = rent[rent['Location'] == 'Portland, OR']
# portland_rent.describe()

# %% [markdown]
# portland_rent

# %% [markdown]
# ### Zillow rent data
# - Data probably much more reliable, uses their Rent Zestimates algorithms to track the rental data, includes locations that aren't currently listed. Only extends to 2017 data
# - only shows overall average per neighborhood
# - price per sq ftage.. how will i compare to the airbnb data?

# %%
zillow = pd.read_csv('zillow-pricepersqft.csv')

# %%
zillow_OR = zillow[(zillow['Metro']=='Portland') & (zillow['State']=='OR')]
zillow_OR.head()
# Out:
#      City Code       City     Metro      County State  Population Rank  \
# 29       13373   Portland  Portland   Multnomah    OR               30
# 322      30381  Beaverton  Portland  Washington    OR              323
# 380      11914  Hillsboro  Portland  Washington    OR              381
# 578      24967    Gresham  Portland   Multnomah    OR              579
# 860      30177      Aloha  Portland  Washington    OR              861
#
#      November 2010  December 2010  January 2011  February 2011  March 2011  \
# 29           1.020          1.018         1.018          1.022       1.028
# 322          0.838          0.846         0.848          0.844       0.844
# 380          0.798          0.810         0.814          0.814       0.812
# 578          0.848          0.838         0.830          0.824       0.822
# 860          0.850          0.860         0.860          0.854       0.846
#
#      April 2011  May 2011  June 2011  July 2011      ...       November 2015  \
# 29        1.032     1.036      1.038      1.042      ...               1.434
# 322       0.844     0.846      0.852      0.856      ...               1.092
# 380       0.812     0.812      0.816      0.816      ...               1.024
# 578       0.818     0.816      0.814      0.818      ...               1.080
# 860       0.842     0.842      0.846      0.848      ...               1.076
#
#      December 2015  January 2016  February 2016  March 2016  April 2016  \
# 29           1.444         1.456          1.464       1.476       1.486
# 322          1.098         1.106          1.112       1.124       1.134
# 380          1.028         1.036          1.044       1.054       1.066
# 578          1.082         1.088          1.098       1.110       1.120
# 860          1.082         1.090          1.098       1.112       1.124
#
#      May 2016  June 2016  July 2016  August 2016  September 2016  \
# 29      1.498      1.506      1.510        1.512           1.516
# 322     1.146      1.156      1.162        1.168           1.174
# 380     1.076      1.086      1.090        1.092           1.096
# 578     1.130      1.138      1.142        1.144           1.146
# 860     1.136      1.144      1.148        1.152           1.160
#
#      October 2016  November 2016  December 2016  January 2017
# 29          1.520          1.524          1.524         1.520
# 322         1.178          1.182          1.182         1.178
# 380         1.100          1.102          1.102         1.100
# 578         1.152          1.154          1.158         1.160
# 860         1.168          1.176          1.176         1.172
#
# [5 rows x 81 columns]

# %%
zillow_OR
