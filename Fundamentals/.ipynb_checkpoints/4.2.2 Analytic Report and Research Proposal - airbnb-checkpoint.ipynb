# %% [markdown]
# # Factors to consider in becoming an Airbnb host
# ## Analytics report and research proposal
#
# By Cindy Barrientos
#
# ### Introduction
# Airbnb has just celebrated its 10th year in operations. Many have built successful side incomes, or have even made Airbnb hosting their primary source of income. The question you may be asking now is, should you become an Airbnb host? If so, what do you need to consider to be a successful and profitable host? This report seeks to provide more information with regards to becoming an Airbnb host in Portland, Oregon.

# %% [markdown]
# ## Questions I'd like to address:
#
# ### Does location have an effect on Airbnb listing prices?
#
#
# ### How can one maximize their listing price on Airbnb?
#
#
# ### Why doesn't high overall reviews lead to a higher cost in price per night?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
pd.options.display.max_columns=30

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
#plt.rcParams({'font.size': 22})

# %% [markdown]
# ## AirBnB data
# The following data was obtained from: http://insideairbnb.com/about.html
#
# Inside AirBnB is an independent, non-commercial entity offering open source access to data that has been scraped from listings on the AirBnB website. Their offerings include detailed listing, calendar availability, reviews, and GeoJSON data. For the purposes here, only the detailed listings are used.

# %%
full_OR_airbnb = pd.read_csv('listings.csv.gz', compression='gzip')

# %%
full_OR_airbnb.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
full_OR_airbnb.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   7893   https://www.airbnb.com/rooms/7893  20181107122123   2018-11-07
# 1  12899  https://www.airbnb.com/rooms/12899  20181107122123   2018-11-07
# 2  16688  https://www.airbnb.com/rooms/16688  20181107122123   2018-11-07
# 3  25200  https://www.airbnb.com/rooms/25200  20181107122123   2018-11-07
# 4  26203  https://www.airbnb.com/rooms/26203  20181107122123   2018-11-07
#
#                                                 name  \
# 0                           North Williams 2brm Home
# 1  Alberta Arts 2 bedroom suite, charming 1906 house
# 2     Beautiful condo in downtown Pearl, NW Portland
# 3             Flamenco Dream :: hip mississippi ave.
# 4                     Bluebird @ hip mississippi ave
#
#                                              summary  \
# 0  Located on Williams bike corridor, some of Por...
# 1  Settle in to a space of your own. You'll have ...
# 2  Newly remodeled 2 bedroom (3 queen beds), 2 fu...
# 3  If you are an Urban Farming pioneer, enthusias...
# 4  If you are an Urban Farming pioneer, enthusias...
#
#                                                space  \
# 0  This NE Portland 2 bedroom home is located jus...
# 1  We live in a neighborhood of beautiful gardens...
# 2  - Fully furnished condo with high ceilings, bi...
# 3  The large farmhouse is surrounded by magical u...
# 4  The large farmhouse is surrounded by magical u...
#
#                                          description experiences_offered  \
# 0  Located on Williams bike corridor, some of Por...                none
# 1  Settle in to a space of your own. You'll have ...                none
# 2  Newly remodeled 2 bedroom (3 queen beds), 2 fu...                none
# 3  If you are an Urban Farming pioneer, enthusias...                none
# 4  If you are an Urban Farming pioneer, enthusias...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  We're within walking distance of a grocery and...
# 2  Easily one of Portland’s most desirable neighb...
# 3  Tierra Soul is located in the fun and hip Miss...
# 4  We are located in the fun and hip Mississippi ...
#
#                                                notes  \
# 0                                                NaN
# 1  We welcome musicians and even have a guitar fo...
# 2  - Smoking is strictly prohibited - Must be abl...
# 3  QUIET HOURS: (9pm -7am) We have guests from al...
# 4  QUIET HOURS: (9pm -7am) We have guests from al...
#
#                                              transit  \
# 0                                                NaN
# 1  Parking is readily available in front of our h...
# 2  Walking distance to the public Light Rail, bus...
# 3  We are a 5 minute drive, and 10 minute MAX rid...
# 4  We are a 5 minute drive, and 10 minute MAX rid...
#
#                                               access  \
# 0                                                NaN
# 1  Guests have the whole upstairs, two bedrooms, ...
# 2  Our guests enjoy entire home to themselves. Di...
# 3                                                NaN
# 4                                                NaN
#
#                                          interaction  \
# 0                                                NaN
# 1  We let our guests determine their level of int...
# 2  Our guests can reach us via phone, text or email.
# 3                                                NaN
# 4                                                NaN
#
#                                          house_rules        ...         \
# 0                                                NaN        ...
# 1  Please no smoking. The space is not child-proo...        ...
# 2                                                NaN        ...
# 3  quiet-ish hours: 9pm - 7am     this means we a...        ...
# 4  quiet-ish hours: 9pm - 7am     this means we a...        ...
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                        9.0                   10.0
# 4                       10.0                    9.0
#
#   review_scores_communication  review_scores_location  review_scores_value  \
# 0                        10.0                    10.0                 10.0
# 1                        10.0                    10.0                 10.0
# 2                        10.0                    10.0                  9.0
# 3                        10.0                    10.0                  9.0
# 4                        10.0                    10.0                  9.0
#
#   requires_license                license                 jurisdiction_names  \
# 0                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
# 1                t    14-218887-000-00-HO  {OREGON," MULTNOMAH"," PORTLAND"}
# 2                t  2008-190040-000-00-RS  {OREGON," MULTNOMAH"," PORTLAND"}
# 3                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
# 4                t                    NaN  {OREGON," MULTNOMAH"," PORTLAND"}
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     flexible
# 1                f                        f                     moderate
# 2                t                        f                     moderate
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture  require_guest_phone_verification  \
# 0                             f                                 f
# 1                             f                                 f
# 2                             f                                 f
# 3                             f                                 f
# 4                             f                                 f
#
#   calculated_host_listings_count reviews_per_month
# 0                              1              0.02
# 1                              1              4.67
# 2                              1              2.37
# 3                              6              0.33
# 4                              6              0.27
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Cleaning the data
#
# There is more data here than is necessary for our purposes. Below, I will do a bit of data cleaning and refining to prepare for analytics, such as:
# 1. remove excess columns
# 2. fix price column such that the '%' and ',' symbols are dropped, then turn into a floating point
# 3. remove listings that are valued at greater than USD500/night

# %% [markdown]
# #### Removing excess column data

# %%
airbnb = full_OR_airbnb.drop(columns=['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate', 'host_total_listings_count', 'neighbourhood_group_cleansed', 
                                      'requires_license', 'license', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 
                                      'calendar_last_scraped', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'street', 
                                      'host_verifications', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'scrape_id',
                                      'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
                                      'house_rules', 'picture_url', 'host_id', 'host_url', 'square_feet', 'weekly_price', 'monthly_price', 'neighbourhood', 'require_guest_profile_picture',                                              
                                      'require_guest_phone_verification', 'calculated_host_listings_count'])
airbnb.describe()
# Out:
#                  id  host_listings_count  accommodates    bathrooms  \
# count  5.317000e+03          5312.000000   5317.000000  5314.000000
# mean   1.531575e+07            12.256589      3.435960     1.230335
# std    8.481055e+06           114.287981      1.898449     0.510583
# min    7.893000e+03             0.000000      1.000000     0.000000
# 25%    7.959145e+06             1.000000      2.000000     1.000000
# 50%    1.625721e+07             1.000000      3.000000     1.000000
# 75%    2.188217e+07             2.000000      4.000000     1.000000
# max    2.986167e+07          1305.000000     24.000000     5.000000
#
#           bedrooms         beds  guests_included  minimum_nights  \
# count  5315.000000  5316.000000      5317.000000     5317.000000
# mean      1.359172     1.869451         1.811360        4.221930
# std       0.901567     1.230026         1.292145       10.049577
# min       0.000000     0.000000         1.000000        1.000000
# 25%       1.000000     1.000000         1.000000        1.000000
# 50%       1.000000     2.000000         1.000000        2.000000
# 75%       2.000000     2.000000         2.000000        2.000000
# max       8.000000    16.000000        15.000000      222.000000
#
#        maximum_nights  number_of_reviews  review_scores_rating  \
# count     5317.000000        5317.000000           4846.000000
# mean       489.343051          60.934173             96.931077
# std        534.905799          81.961679              4.410958
# min          1.000000           0.000000             20.000000
# 25%         21.000000           6.000000             96.000000
# 50%         90.000000          29.000000             98.000000
# 75%       1125.000000          84.000000            100.000000
# max       5000.000000         865.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4844.000000                4843.000000
# mean                 9.880058                   9.784844
# std                  0.426587                   0.548327
# min                  2.000000                   2.000000
# 25%                 10.000000                  10.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4841.000000                  4842.000000
# mean                9.940921                     9.932879
# std                 0.302573                     0.341687
# min                 5.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count             4841.000000          4841.000000        4877.000000
# mean                 9.790126             9.739103           3.013443
# std                  0.477763             0.551386           2.920180
# min                  4.000000             2.000000           0.010000
# 25%                 10.000000            10.000000           0.780000
# 50%                 10.000000            10.000000           2.380000
# 75%                 10.000000            10.000000           4.450000
# max                 10.000000            10.000000          58.160000

# %%
airbnb.head()
# Out:
#       id                         listing_url      host_name  host_since  \
# 0   7893   https://www.airbnb.com/rooms/7893          Jesse  2009-06-14
# 1  12899  https://www.airbnb.com/rooms/12899  Ali And David  2009-10-29
# 2  16688  https://www.airbnb.com/rooms/16688         Ashish  2009-12-21
# 3  25200  https://www.airbnb.com/rooms/25200         Garden  2010-04-05
# 4  26203  https://www.airbnb.com/rooms/26203         Garden  2010-04-05
#
#    host_response_time host_response_rate host_is_superhost  \
# 0                 NaN                NaN                 f
# 1                 NaN                NaN                 t
# 2      within an hour               100%                 t
# 3  within a few hours               100%                 f
# 4  within a few hours               100%                 f
#
#    host_listings_count host_has_profile_pic host_identity_verified  \
# 0                  1.0                    t                      f
# 1                  1.0                    t                      t
# 2                  1.0                    t                      f
# 3                  7.0                    t                      t
# 4                  7.0                    t                      t
#
#   neighbourhood_cleansed      city state zipcode property_type  \
# 0               Piedmont  Portland    OR   97217         House
# 1              Concordia  Portland    OR   97211   Guest suite
# 2                  Pearl  Portland    OR   97209         House
# 3               Humboldt  Portland    OR   97217         House
# 4               Humboldt  Portland    OR   97217         House
#
#          ...         number_of_reviews  first_review  last_review  \
# 0        ...                         2    2010-02-22   2014-08-12
# 1        ...                       500    2010-01-24   2018-10-21
# 2        ...                        44    2017-04-30   2018-11-04
# 3        ...                        34    2010-06-07   2018-10-18
# 4        ...                        28    2010-06-09   2018-09-30
#
#    review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 0                 100.0                    10.0                      10.0
# 1                  98.0                    10.0                      10.0
# 2                  97.0                    10.0                      10.0
# 3                  93.0                     9.0                       9.0
# 4                  92.0                     9.0                      10.0
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  10.0                        10.0                   10.0
# 1                  10.0                        10.0                   10.0
# 2                  10.0                        10.0                   10.0
# 3                  10.0                        10.0                   10.0
# 4                   9.0                        10.0                   10.0
#
#   review_scores_value                 jurisdiction_names instant_bookable  \
# 0                10.0  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1                10.0  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2                 9.0  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3                 9.0  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4                 9.0  {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#    is_business_travel_ready          cancellation_policy  reviews_per_month
# 0                         f                     flexible               0.02
# 1                         f                     moderate               4.67
# 2                         f                     moderate               2.37
# 3                         f  strict_14_with_grace_period               0.33
# 4                         f  strict_14_with_grace_period               0.27
#
# [5 rows x 44 columns]

# %% [markdown]
# There is still 43 columns of data.

# %% [markdown]
# #### Refining price data
# First, to make the price data useable, I have to remove the symbols ('$' and ',') and set them as floats. Then, I'll check the integrity of the price data.

# %%
airbnb.price = [x.strip('$') for x in airbnb.price]
airbnb.price = airbnb.price.str.replace(',', '')

# %%
airbnb.dtypes
airbnb['price'] = airbnb['price'].astype('float')

# %% [markdown]
# Now that the prices are floating point integers, I'll look through some of the outliers

# %%
airbnb.price.max()
# Out:
# 8400.0

# %% [markdown]
# I don't believe there is really an AirBnB listing available for $8400. As it turns out in searching the listing URL, the cost is 84/night:

# %%
full_OR_airbnb.loc[airbnb['price']==8400]
# Out:
#           id                           listing_url       scrape_id  \
# 836  4684661  https://www.airbnb.com/rooms/4684661  20181107122123
#
#     last_scraped                              name summary  \
# 836   2018-11-07  Charming quiet bohemian getaway!     NaN
#
#                                                  space  \
# 836  You have your own private entrance into the fl...
#
#                                            description experiences_offered  \
# 836  You have your own private entrance into the fl...                none
#
#                                  neighborhood_overview notes  \
# 836  A great place to walk around, fruit trees and ...   NaN
#
#                                                transit  \
# 836  Public transportattion is nearby and I have un...
#
#                                                 access  \
# 836  You have the entire upstairs which consists of...
#
#                                            interaction  \
# 836  Since I live in the house you have ready acces...
#
#                                            house_rules        ...         \
# 836  No Smoking - I have had new carpets put in as ...        ...
#
#      review_scores_cleanliness  review_scores_checkin  \
# 836                       10.0                   10.0
#
#     review_scores_communication  review_scores_location  review_scores_value  \
# 836                        10.0                    10.0                 10.0
#
#     requires_license              license                 jurisdiction_names  \
# 836                t  15-131548-000-00-HO  {OREGON," MULTNOMAH"," PORTLAND"}
#
#     instant_bookable is_business_travel_ready cancellation_policy  \
# 836                t                        f            moderate
#
#     require_guest_profile_picture  require_guest_phone_verification  \
# 836                             f                                 f
#
#     calculated_host_listings_count reviews_per_month
# 836                              1              3.42
#
# [1 rows x 96 columns]

# %%
airbnb.at[836, 'price'] = 84.00
airbnb.price.max()
# Out:
# 2835.0

# %% [markdown]
# The next highest listing is no longer available, so I cannot verify that it is correct. There are a handful of listings today 12/18/2018 that are above USD1500, but they are meant as retreats or special events. Most people will not be able to utilize investment opportunities in such large and expensive properties, so I'll limit my data up to $500 per night.

# %%
airbnb = airbnb[airbnb['price']<=500]
airbnb.price.describe()
# Out:
# count    5285.000000
# mean      110.112772
# std        71.466615
# min         0.000000
# 25%        65.000000
# 50%        90.000000
# 75%       129.000000
# max       500.000000
# Name: price, dtype: float64

# %%
airbnb.loc[airbnb['price']==0.00]
# Out:
#             id                            listing_url host_name  host_since  \
# 3576  20477753  https://www.airbnb.com/rooms/20477753      Leah  2012-04-24
#
#      host_response_time host_response_rate host_is_superhost  \
# 3576     within an hour               100%                 t
#
#       host_listings_count host_has_profile_pic host_identity_verified  \
# 3576                  2.0                    t                      f
#
#      neighbourhood_cleansed      city state zipcode property_type  \
# 3576                 Sumner  Portland    OR   97220         House
#
#             ...         number_of_reviews  first_review  last_review  \
# 3576        ...                        81    2017-08-23   2018-09-23
#
#       review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 3576                 100.0                    10.0                      10.0
#
#      review_scores_checkin  review_scores_communication  \
# 3576                  10.0                         10.0
#
#      review_scores_location review_scores_value  \
# 3576                   10.0                10.0
#
#                      jurisdiction_names instant_bookable  \
# 3576  {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#       is_business_travel_ready  cancellation_policy  reviews_per_month
# 3576                         f             moderate                5.5
#
# [1 rows x 44 columns]

# %% [markdown]
# Another typo indicating the listing index 3576 above is not actually USD0.00 but rather $29.00 according to the current listing; will fix below:

# %%
airbnb.at[3576, 'price'] = 29.00
airbnb.price.min()
# Out:
# 10.0

# %%
airbnb.loc[airbnb['price']<29.00]
# Out:
#             id                            listing_url            host_name  \
# 32      114086    https://www.airbnb.com/rooms/114086               Teresa
# 61      236108    https://www.airbnb.com/rooms/236108               Teresa
# 117     573191    https://www.airbnb.com/rooms/573191               Deanna
# 822    4606687   https://www.airbnb.com/rooms/4606687                Sonja
# 1055   6172997   https://www.airbnb.com/rooms/6172997        Monica-Sophie
# 1776  11099643  https://www.airbnb.com/rooms/11099643                Aimie
# 1807  11291213  https://www.airbnb.com/rooms/11291213             Michelle
# 1828  11533779  https://www.airbnb.com/rooms/11533779        Monica-Sophie
# 1848  11675192  https://www.airbnb.com/rooms/11675192        Monica-Sophie
# 1956  12473284  https://www.airbnb.com/rooms/12473284                Fiona
# 1958  12474892  https://www.airbnb.com/rooms/12474892        Monica-Sophie
# 2014  12892478  https://www.airbnb.com/rooms/12892478                Julie
# 2110  13391691  https://www.airbnb.com/rooms/13391691                Julie
# 2127  13477153  https://www.airbnb.com/rooms/13477153             Benjamin
# 2265  14104990  https://www.airbnb.com/rooms/14104990                Jenna
# 2324  14448166  https://www.airbnb.com/rooms/14448166                Urban
# 2362  14731137  https://www.airbnb.com/rooms/14731137        Monica-Sophie
# 2399  14881526  https://www.airbnb.com/rooms/14881526                 Eric
# 2544  15646823  https://www.airbnb.com/rooms/15646823              Sheilah
# 2647  16193566  https://www.airbnb.com/rooms/16193566                 Rose
# 2710  16603125  https://www.airbnb.com/rooms/16603125                Julie
# 2964  18078713  https://www.airbnb.com/rooms/18078713                  Dan
# 3026  18412868  https://www.airbnb.com/rooms/18412868               Carole
# 3071  18636900  https://www.airbnb.com/rooms/18636900        Tony And Sean
# 3132  18918121  https://www.airbnb.com/rooms/18918121        Tony And Sean
# 3146  18962800  https://www.airbnb.com/rooms/18962800        Tony And Sean
# 3157  19001094  https://www.airbnb.com/rooms/19001094        Tony And Sean
# 3187  19123366  https://www.airbnb.com/rooms/19123366            Christine
# 3275  19490371  https://www.airbnb.com/rooms/19490371       Jason + Claire
# 3297  19569616  https://www.airbnb.com/rooms/19569616               Thomas
# 3769  21140863  https://www.airbnb.com/rooms/21140863                    飞
# 3793  21254448  https://www.airbnb.com/rooms/21254448                 Rose
# 3796  21267200  https://www.airbnb.com/rooms/21267200    J Hall Properties
# 3855  21513288  https://www.airbnb.com/rooms/21513288    J Hall Properties
# 3948  21798220  https://www.airbnb.com/rooms/21798220                Dylan
# 4060  22336173  https://www.airbnb.com/rooms/22336173               Willis
# 4061  22343113  https://www.airbnb.com/rooms/22343113          Bao (Grace)
# 4149  22689527  https://www.airbnb.com/rooms/22689527        Tony And Sean
# 4187  22835252  https://www.airbnb.com/rooms/22835252  Lathen & Anne-Marie
# 4396  24202231  https://www.airbnb.com/rooms/24202231                Kelly
# 4416  24309485  https://www.airbnb.com/rooms/24309485                 Ryan
# 4433  24414311  https://www.airbnb.com/rooms/24414311              Arielle
# 4618  25381271  https://www.airbnb.com/rooms/25381271                  Eri
# 4619  25400139  https://www.airbnb.com/rooms/25400139                Amber
# 5014  27752929  https://www.airbnb.com/rooms/27752929               Joshua
# 5023  27789196  https://www.airbnb.com/rooms/27789196                 Anne
# 5094  28339395  https://www.airbnb.com/rooms/28339395              Richard
# 5161  28845510  https://www.airbnb.com/rooms/28845510                 Judy
# 5261  29493388  https://www.airbnb.com/rooms/29493388               Carole
# 5292  29762464  https://www.airbnb.com/rooms/29762464          Bao (Grace)
#
#       host_since  host_response_time host_response_rate host_is_superhost  \
# 32    2011-04-11                 NaN                NaN                 f
# 61    2011-04-11                 NaN                NaN                 f
# 117   2009-08-18        within a day                75%                 f
# 822   2014-08-30  within a few hours               100%                 f
# 1055  2013-04-26  within a few hours               100%                 f
# 1776  2016-02-06                 NaN                NaN                 f
# 1807  2012-09-03                 NaN                NaN                 f
# 1828  2013-04-26  within a few hours               100%                 f
# 1848  2013-04-26  within a few hours               100%                 f
# 1956  2014-09-21      within an hour               100%                 f
# 1958  2013-04-26  within a few hours               100%                 f
# 2014  2012-04-05                 NaN                NaN                 f
# 2110  2012-04-05                 NaN                NaN                 f
# 2127  2014-07-03                 NaN                NaN                 f
# 2265  2016-07-20                 NaN                NaN                 f
# 2324  2016-08-03      within an hour               100%                 t
# 2362  2013-04-26  within a few hours               100%                 f
# 2399  2016-09-03  within a few hours               100%                 t
# 2544  2016-04-15      within an hour               100%                 t
# 2647  2012-09-19                 NaN                NaN                 f
# 2710  2012-08-10      within an hour               100%                 f
# 2964  2017-03-28                 NaN                NaN                 f
# 3026  2017-04-25      within an hour               100%                 t
# 3071  2014-07-06                 NaN                NaN                 t
# 3132  2014-07-06                 NaN                NaN                 t
# 3146  2014-07-06                 NaN                NaN                 t
# 3157  2014-07-06                 NaN                NaN                 t
# 3187  2017-05-30                 NaN                NaN                 f
# 3275  2017-06-24      within an hour               100%                 t
# 3297  2017-06-28                 NaN                NaN                 f
# 3769  2015-12-10                 NaN                NaN                 f
# 3793  2012-09-19                 NaN                NaN                 f
# 3796  2017-10-08      within an hour               100%                 f
# 3855  2017-10-08      within an hour               100%                 f
# 3948  2017-10-20      within an hour               100%                 f
# 4060  2010-01-02      within an hour               100%                 t
# 4061  2016-12-16      within an hour               100%                 f
# 4149  2014-07-06                 NaN                NaN                 t
# 4187  2014-12-25                 NaN                NaN                 f
# 4396  2016-10-16      within an hour               100%                 t
# 4416  2015-02-04      within an hour               100%                 t
# 4433  2015-07-27                 NaN                NaN                 f
# 4618  2013-01-12                 NaN                NaN                 t
# 4619  2013-10-15                 NaN                NaN                 f
# 5014  2018-08-14      within an hour               100%                 f
# 5023  2018-08-16      within an hour               100%                 f
# 5094  2016-03-20      within an hour               100%                 f
# 5161  2015-11-21      within an hour               100%                 f
# 5261  2018-10-19        within a day               100%                 f
# 5292  2016-12-16      within an hour               100%                 f
#
#       host_listings_count host_has_profile_pic host_identity_verified  \
# 32                    5.0                    t                      t
# 61                    5.0                    t                      t
# 117                   1.0                    t                      f
# 822                   2.0                    t                      f
# 1055                  6.0                    t                      f
# 1776                  1.0                    t                      f
# 1807                  1.0                    t                      f
# 1828                  6.0                    t                      f
# 1848                  6.0                    t                      f
# 1956                  4.0                    t                      t
# 1958                  6.0                    t                      f
# 2014                  7.0                    t                      t
# 2110                  7.0                    t                      t
# 2127                  1.0                    t                      f
# 2265                  1.0                    t                      f
# 2324                  2.0                    t                      f
# 2362                  6.0                    t                      f
# 2399                  1.0                    t                      f
# 2544                  2.0                    t                      t
# 2647                  2.0                    t                      f
# 2710                  6.0                    t                      t
# 2964                  3.0                    t                      f
# 3026                  1.0                    t                      f
# 3071                  5.0                    t                      t
# 3132                  5.0                    t                      t
# 3146                  5.0                    t                      t
# 3157                  5.0                    t                      t
# 3187                  1.0                    t                      f
# 3275                  1.0                    t                      f
# 3297                  1.0                    t                      f
# 3769                  1.0                    t                      f
# 3793                  2.0                    t                      f
# 3796                  2.0                    t                      f
# 3855                  2.0                    t                      f
# 3948                  2.0                    t                      f
# 4060                  2.0                    t                      t
# 4061                  2.0                    t                      t
# 4149                  5.0                    t                      t
# 4187                  3.0                    t                      t
# 4396                  2.0                    t                      t
# 4416                  3.0                    t                      t
# 4433                  1.0                    t                      t
# 4618                  2.0                    t                      t
# 4619                  1.0                    t                      t
# 5014                  1.0                    t                      f
# 5023                  3.0                    t                      f
# 5094                  1.0                    t                      t
# 5161                  1.0                    t                      f
# 5261                  1.0                    t                      f
# 5292                  2.0                    t                      t
#
#      neighbourhood_cleansed      city state zipcode property_type  \
# 32                    Sabin  Portland    OR   97211         House
# 61                    Sabin  Portland    OR   97211         House
# 117               Irvington  Portland    OR   97212     Apartment
# 822    Brentwood-Darlington  Portland    OR   97206      Bungalow
# 1055    Powellhurst-Gilbert  Portland    OR   97266     Townhouse
# 1776             Montavilla  Portland    OR   97216         House
# 1807                Buckman  Portland    OR   97214     Apartment
# 1828    Powellhurst-Gilbert  Portland    OR   97266     Townhouse
# 1848    Powellhurst-Gilbert  Portland    OR   97266     Townhouse
# 1956              Sunnyside  Portland    OR   97214         House
# 1958    Powellhurst-Gilbert  Portland    OR   97266     Townhouse
# 2014    Powellhurst-Gilbert  Portland    OR   97236         House
# 2110    Powellhurst-Gilbert  Portland    OR   97236         House
# 2127       Mt. Scott-Arleta  Portland    OR   97206         House
# 2265              Hazelwood  Portland    OR   97216     Townhouse
# 2324             Montavilla  Portland    OR   97215         House
# 2362    Powellhurst-Gilbert  Portland    OR   97266     Townhouse
# 2399             Montavilla  Portland    OR   97213         House
# 2544               Overlook  Portland    OR   97217         House
# 2647                Buckman  Portland    OR   97214         House
# 2710               Piedmont  Portland    OR   97211         House
# 2964      Portland Downtown  Portland    OR   97201     Apartment
# 3026            South Tabor  Portland    OR   97206     Treehouse
# 3071                  Sabin  Portland    OR   97212   Guest suite
# 3132                  Sabin  Portland    OR   97212         House
# 3146                  Sabin  Portland    OR   97212         House
# 3157                  Sabin  Portland    OR   97212         House
# 3187                   King  Portland    OR   97211         House
# 3275              Woodstock  Portland    OR   97206      Bungalow
# 3297              St. Johns  Portland    OR   97203         House
# 3769             Centennial  Portland    OR   97233     Apartment
# 3793                Buckman  Portland    OR   97214         House
# 3796              Hazelwood  Portland    OR   97220         House
# 3855              Hazelwood  Portland    OR   97220         House
# 3948              Hazelwood  Portland    OR   97233         House
# 4060              Hazelwood  Portland    OR   97216         House
# 4061    Powellhurst-Gilbert  Portland    OR   97236         House
# 4149                   King  Portland    OR   97212         House
# 4187              Hillsdale  Portland    OR   97239         House
# 4396              St. Johns  Portland    OR   97203         House
# 4416                 Kenton  Portland    OR   97217         House
# 4433                   King  Portland    OR   97211         House
# 4618              Woodstock  Portland    OR   97206         House
# 4619              St. Johns  Portland    OR   97203         House
# 5014                 Kenton  Portland    OR     NaN   Guest suite
# 5023              Mill Park  Portland    OR   97233         House
# 5094   Brentwood-Darlington  Portland    OR   97206           Bus
# 5161                  Cully  Portland    OR   97218         House
# 5261              Irvington  Portland    OR   97212         House
# 5292    Powellhurst-Gilbert  Portland    OR   97236         House
#
#             ...         number_of_reviews  first_review  last_review  \
# 32          ...                        54    2011-07-06   2017-11-18
# 61          ...                        55    2012-04-26   2018-10-21
# 117         ...                       134    2013-05-08   2017-07-23
# 822         ...                         0           NaN          NaN
# 1055        ...                         4    2015-05-16   2017-09-22
# 1776        ...                        15    2016-02-20   2016-10-31
# 1807        ...                         0           NaN          NaN
# 1828        ...                         4    2016-04-24   2018-08-31
# 1848        ...                         1    2016-04-12   2016-04-12
# 1956        ...                       114    2016-05-05   2018-10-23
# 1958        ...                         2    2016-09-21   2017-08-12
# 2014        ...                         6    2016-06-06   2018-09-19
# 2110        ...                         7    2016-11-01   2017-11-26
# 2127        ...                         0           NaN          NaN
# 2265        ...                         0           NaN          NaN
# 2324        ...                        73    2016-08-20   2018-10-21
# 2362        ...                         0           NaN          NaN
# 2399        ...                        93    2016-09-05   2018-10-07
# 2544        ...                       146    2016-10-30   2018-10-29
# 2647        ...                        82    2017-03-12   2018-10-14
# 2710        ...                         5    2017-01-05   2018-08-22
# 2964        ...                        19    2017-04-13   2017-06-21
# 3026        ...                       164    2017-04-29   2018-11-04
# 3071        ...                       125    2017-05-28   2018-11-04
# 3132        ...                        67    2017-06-05   2018-09-17
# 3146        ...                        67    2017-06-04   2018-10-31
# 3157        ...                        32    2017-08-17   2018-10-21
# 3187        ...                         7    2017-06-16   2017-07-19
# 3275        ...                        27    2017-09-05   2018-09-21
# 3297        ...                         3    2017-08-12   2017-08-16
# 3769        ...                         5    2017-10-04   2017-11-03
# 3793        ...                        28    2017-10-24   2018-11-04
# 3796        ...                        39    2017-11-22   2018-10-23
# 3855        ...                        41    2017-11-02   2018-10-21
# 3948        ...                        66    2017-11-17   2018-10-25
# 4060        ...                        25    2018-06-18   2018-11-03
# 4061        ...                         0           NaN          NaN
# 4149        ...                         6    2018-01-14   2018-10-21
# 4187        ...                        40    2018-02-04   2018-10-15
# 4396        ...                         7    2018-07-16   2018-09-30
# 4416        ...                         2    2018-05-28   2018-06-04
# 4433        ...                         1    2018-05-23   2018-05-23
# 4618        ...                        15    2018-06-04   2018-08-14
# 4619        ...                        33    2018-06-06   2018-10-11
# 5014        ...                        12    2018-09-26   2018-11-04
# 5023        ...                        20    2018-08-17   2018-10-28
# 5094        ...                         1    2018-10-13   2018-10-13
# 5161        ...                         3    2018-10-12   2018-11-02
# 5261        ...                         0           NaN          NaN
# 5292        ...                         1    2018-11-04   2018-11-04
#
#       review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 32                    89.0                     9.0                       9.0
# 61                    91.0                     9.0                       9.0
# 117                   87.0                     9.0                       8.0
# 822                    NaN                     NaN                       NaN
# 1055                  80.0                     9.0                       9.0
# 1776                  96.0                    10.0                       9.0
# 1807                   NaN                     NaN                       NaN
# 1828                  95.0                    10.0                       9.0
# 1848                  80.0                     8.0                       8.0
# 1956                  85.0                     9.0                       8.0
# 1958                  90.0                    10.0                       8.0
# 2014                  70.0                     9.0                       8.0
# 2110                  97.0                    10.0                      10.0
# 2127                   NaN                     NaN                       NaN
# 2265                   NaN                     NaN                       NaN
# 2324                  95.0                    10.0                      10.0
# 2362                   NaN                     NaN                       NaN
# 2399                  97.0                    10.0                       9.0
# 2544                  98.0                    10.0                      10.0
# 2647                  97.0                    10.0                      10.0
# 2710                  92.0                     9.0                       9.0
# 2964                  84.0                     9.0                       9.0
# 3026                  98.0                    10.0                      10.0
# 3071                  99.0                    10.0                      10.0
# 3132                 100.0                    10.0                      10.0
# 3146                  99.0                    10.0                      10.0
# 3157                  99.0                    10.0                      10.0
# 3187                 100.0                    10.0                      10.0
# 3275                  99.0                    10.0                      10.0
# 3297                 100.0                    10.0                      10.0
# 3769                  88.0                    10.0                      10.0
# 3793                  98.0                    10.0                      10.0
# 3796                  88.0                     9.0                       9.0
# 3855                  85.0                     9.0                       9.0
# 3948                  89.0                     9.0                       9.0
# 4060                  94.0                    10.0                      10.0
# 4061                   NaN                     NaN                       NaN
# 4149                 100.0                    10.0                      10.0
# 4187                  94.0                    10.0                      10.0
# 4396                 100.0                    10.0                      10.0
# 4416                  90.0                    10.0                       9.0
# 4433                 100.0                     8.0                       8.0
# 4618                  99.0                    10.0                      10.0
# 4619                  86.0                     9.0                       8.0
# 5014                  98.0                    10.0                      10.0
# 5023                  87.0                     9.0                       9.0
# 5094                 100.0                    10.0                      10.0
# 5161                  93.0                    10.0                       9.0
# 5261                   NaN                     NaN                       NaN
# 5292                 100.0                    10.0                      10.0
#
#      review_scores_checkin  review_scores_communication  \
# 32                    10.0                         10.0
# 61                    10.0                          9.0
# 117                    9.0                         10.0
# 822                    NaN                          NaN
# 1055                   9.0                          8.0
# 1776                  10.0                          9.0
# 1807                   NaN                          NaN
# 1828                  10.0                         10.0
# 1848                   8.0                          8.0
# 1956                   9.0                          9.0
# 1958                  10.0                         10.0
# 2014                   9.0                          9.0
# 2110                  10.0                         10.0
# 2127                   NaN                          NaN
# 2265                   NaN                          NaN
# 2324                  10.0                         10.0
# 2362                   NaN                          NaN
# 2399                  10.0                         10.0
# 2544                  10.0                         10.0
# 2647                  10.0                         10.0
# 2710                  10.0                         10.0
# 2964                   9.0                          9.0
# 3026                  10.0                         10.0
# 3071                  10.0                         10.0
# 3132                  10.0                         10.0
# 3146                  10.0                         10.0
# 3157                  10.0                         10.0
# 3187                  10.0                         10.0
# 3275                  10.0                         10.0
# 3297                  10.0                         10.0
# 3769                   8.0                          8.0
# 3793                  10.0                         10.0
# 3796                  10.0                          9.0
# 3855                  10.0                          9.0
# 3948                  10.0                         10.0
# 4060                  10.0                         10.0
# 4061                   NaN                          NaN
# 4149                  10.0                         10.0
# 4187                  10.0                         10.0
# 4396                  10.0                         10.0
# 4416                   9.0                         10.0
# 4433                  10.0                         10.0
# 4618                  10.0                         10.0
# 4619                  10.0                          9.0
# 5014                  10.0                         10.0
# 5023                   9.0                          9.0
# 5094                  10.0                         10.0
# 5161                  10.0                         10.0
# 5261                   NaN                          NaN
# 5292                  10.0                         10.0
#
#      review_scores_location review_scores_value  \
# 32                     10.0                 9.0
# 61                     10.0                 9.0
# 117                     9.0                 9.0
# 822                     NaN                 NaN
# 1055                    8.0                 9.0
# 1776                    9.0                10.0
# 1807                    NaN                 NaN
# 1828                    9.0                10.0
# 1848                    6.0                10.0
# 1956                   10.0                 9.0
# 1958                   10.0                10.0
# 2014                    7.0                 8.0
# 2110                    9.0                10.0
# 2127                    NaN                 NaN
# 2265                    NaN                 NaN
# 2324                   10.0                10.0
# 2362                    NaN                 NaN
# 2399                    9.0                10.0
# 2544                   10.0                10.0
# 2647                   10.0                 9.0
# 2710                   10.0                10.0
# 2964                   10.0                 9.0
# 3026                   10.0                10.0
# 3071                   10.0                10.0
# 3132                   10.0                10.0
# 3146                   10.0                10.0
# 3157                   10.0                 9.0
# 3187                   10.0                10.0
# 3275                   10.0                10.0
# 3297                    9.0                10.0
# 3769                   10.0                 9.0
# 3793                    9.0                10.0
# 3796                    8.0                 9.0
# 3855                    8.0                 9.0
# 3948                    9.0                 9.0
# 4060                    9.0                10.0
# 4061                    NaN                 NaN
# 4149                   10.0                 9.0
# 4187                    9.0                10.0
# 4396                    9.0                10.0
# 4416                    6.0                 9.0
# 4433                   10.0                10.0
# 4618                    9.0                10.0
# 4619                    9.0                10.0
# 5014                   10.0                10.0
# 5023                    9.0                 9.0
# 5094                   10.0                10.0
# 5161                   10.0                10.0
# 5261                    NaN                 NaN
# 5292                   10.0                10.0
#
#                      jurisdiction_names instant_bookable  \
# 32    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 61    {OREGON," MULTNOMAH"," PORTLAND"}                f
# 117   {OREGON," MULTNOMAH"," PORTLAND"}                f
# 822   {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1055  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1776  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1807  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1828  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1848  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 1956  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 1958  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2014  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2110  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2127  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2265  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2324  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 2362  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2399  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2544  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 2647  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2710  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 2964  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3026  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3071  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3132  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3146  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3157  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3187  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3275  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3297  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3769  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3793  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 3796  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3855  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 3948  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4060  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4061  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4149  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4187  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4396  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4416  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4433  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 4618  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 4619  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5014                           {OREGON}                f
# 5023  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5094  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 5161  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5261  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 5292                           {OREGON}                t
#
#       is_business_travel_ready          cancellation_policy  reviews_per_month
# 32                           f  strict_14_with_grace_period               0.60
# 61                           f  strict_14_with_grace_period               0.69
# 117                          f                     flexible               2.00
# 822                          f                     moderate                NaN
# 1055                         f  strict_14_with_grace_period               0.09
# 1776                         f                     moderate               0.45
# 1807                         f                     flexible                NaN
# 1828                         f  strict_14_with_grace_period               0.13
# 1848                         f  strict_14_with_grace_period               0.03
# 1956                         f                     moderate               3.73
# 1958                         f  strict_14_with_grace_period               0.08
# 2014                         f                     flexible               0.20
# 2110                         f                     flexible               0.28
# 2127                         f                     flexible                NaN
# 2265                         f                     flexible                NaN
# 2324                         f                     moderate               2.70
# 2362                         f  strict_14_with_grace_period                NaN
# 2399                         f                     flexible               3.51
# 2544                         f                     flexible               5.93
# 2647                         f                     flexible               4.06
# 2710                         f  strict_14_with_grace_period               0.22
# 2964                         f  strict_14_with_grace_period               0.99
# 3026                         f                     moderate               8.82
# 3071                         f  strict_14_with_grace_period               7.09
# 3132                         f                     moderate               3.86
# 3146                         f                     moderate               3.85
# 3157                         f  strict_14_with_grace_period               2.14
# 3187                         f                     flexible               0.41
# 3275                         f                     flexible               1.89
# 3297                         f                     flexible               0.20
# 3769                         f                     flexible               0.38
# 3793                         f                     moderate               2.21
# 3796                         f                     flexible               3.33
# 3855                         f                     flexible               3.32
# 3948                         f  strict_14_with_grace_period               5.56
# 4060                         f                     flexible               5.24
# 4061                         f                     flexible                NaN
# 4149                         f                     moderate               0.60
# 4187                         f  strict_14_with_grace_period               4.33
# 4396                         f                     flexible               1.83
# 4416                         f  strict_14_with_grace_period               0.37
# 4433                         f  strict_14_with_grace_period               0.18
# 4618                         f                     flexible               2.87
# 4619                         f                     flexible               6.39
# 5014                         f                     moderate               8.37
# 5023                         f                     flexible               7.23
# 5094                         f                     flexible               1.00
# 5161                         f                     moderate               3.00
# 5261                         f                     flexible                NaN
# 5292                         f                     flexible               1.00
#
# [50 rows x 44 columns]

# %% [markdown]
# The listings for USD10.00 seem to be incorrectly priced, though the random ones I checked above USD10.00 and below USD30.00 were correct. For this reason, I will drop the listings with USD10.00

# %%
airbnb = airbnb[airbnb['price']>10.00]

# %% [markdown]
# #### Refining location data
# I need to define how I will separate the location data. I can use either neighborhoods, jurisdictions, or zipcode. In the following I'll look at the data to determine the best approach here.

# %%
airbnb.neighbourhood_cleansed.value_counts().plot(kind="bar")
plt.xlabel('Neighbourhood')
plt.ylabel('Number of listings')
plt.title('AirBnB listings per neighborhood')
plt.show()

# %% [markdown]
# Lots of different neighborhood classifications. Might want to combine some of these for it to be of use, or use jurisdiction

# %%
airbnb.jurisdiction_names.value_counts()
# Out:
# {OREGON," MULTNOMAH"," PORTLAND"}                  5163
# {OREGON}                                             93
# {OREGON," MULTNOMAH"}                                 9
# {OREGON," Washington County"," OR"}                   7
# {OREGON," PORTLAND"}                                  3
# {OREGON," Washington County"," OR"," PORTLAND"}       1
# Name: jurisdiction_names, dtype: int64

# %% [markdown]
# Okay jurisdiction won't be useful either - almost everything is in Multnomah county. Let's get rid of that column data

# %%
airbnb = airbnb.drop(columns='jurisdiction_names')

# %%
airbnb.zipcode.value_counts().plot(kind='bar')
plt.ylabel("Number of listings")
plt.xlabel("Zip code")
plt.title("Number of listings per zip code")
plt.show()

# %% [markdown]
# These have a more digestible amount of categories. I could even remove the last 10 or so because there isn't enough airbnb listings there, suggestings these are not tourist-heavy areas. The data would also be limited to analyze; there are only about 100 listings total in the last 12 zipcodes, so I'd hesitate to trust any conclusions. This leaves 23 different zipcode groupings.
#
#
# Interestingly, the zip code with the highest rental listings is not what I would have suspected as it's not centered in the tourist area. This may be good for interested investors as it may not cost as much to obtain property outside of downtown (can test hypothesis with zillow data later)
#
# Figure out MD code to insert image of Portland metro area with zip codes later: http://toursmaps.com/wp-content/uploads/2016/07/zip_code_map.jpg

# %%
airbnb[airbnb['zipcode']=='97086']
# Out:
#             id                            listing_url host_name  host_since  \
# 2883  17605030  https://www.airbnb.com/rooms/17605030     Larry  2017-03-07
# 5254  29434425  https://www.airbnb.com/rooms/29434425     Kelly  2013-02-22
#
#       host_response_time host_response_rate host_is_superhost  \
# 2883  within a few hours                89%                 f
# 5254                 NaN                NaN                 f
#
#       host_listings_count host_has_profile_pic host_identity_verified  \
# 2883                  1.0                    t                      f
# 5254                  2.0                    t                      t
#
#      neighbourhood_cleansed          city state zipcode property_type  \
# 2883                  Lents  Happy Valley    OR   97086         House
# 5254                  Lents  Happy Valley    OR   97086         House
#
#             ...         maximum_nights  number_of_reviews  first_review  \
# 2883        ...                     31                 30    2017-05-22
# 5254        ...                     60                  0           NaN
#
#       last_review  review_scores_rating review_scores_accuracy  \
# 2883   2018-09-03                  99.0                   10.0
# 5254          NaN                   NaN                    NaN
#
#      review_scores_cleanliness  review_scores_checkin  \
# 2883                      10.0                   10.0
# 5254                       NaN                    NaN
#
#      review_scores_communication review_scores_location  review_scores_value  \
# 2883                        10.0                    9.0                 10.0
# 5254                         NaN                    NaN                  NaN
#
#      instant_bookable  is_business_travel_ready          cancellation_policy  \
# 2883                f                         f                     moderate
# 5254                t                         f  strict_14_with_grace_period
#
#       reviews_per_month
# 2883               1.68
# 5254                NaN
#
# [2 rows x 43 columns]

# %%
lesser_zipcodes = ['97034', '97211-6358', '97225', '97035', '97068', '97222', '97231', '97229', '97230', '97233', '97223', '97086']
airbnb = airbnb[-airbnb['zipcode'].isin(lesser_zipcodes)]

# %% [markdown]
# ### Question: Does location affect listing price?
#
# Now that we have our location variables defined and cleaned, we can determine if there are correlations between zipcode and price per night.

# %%
airbnb.boxplot(column='price', by='zipcode')
plt.ylabel("Price per night")
plt.xlabel("Zipcode")
plt.title("Price per night based on zipcode")
plt.show()

# %% [markdown]
# There is a large variability in price per night lodging by zipcode. Therefore, zipcode may not be a huge factor in setting up an AirBnB.
#
# At this point, I will find the zip codes with the highest and lowest mean price and use a statistical test to determine if there is a real difference between the two groups to answer whether zip codes matter in listing higher prices.

# %%
# Scan here for zipcodes with the highest and lowest mean listing price
airbnb.groupby('zipcode').price.mean().plot(kind='bar')
plt.ylabel("Average price per night")
plt.xlabel("Zipcode")
plt.title("Average listing price per zipcode")
plt.show()

# %%
prices_97205 = airbnb[airbnb['zipcode']=='97205'].price
prices_97236 = airbnb[airbnb['zipcode']=='97236'].price

# %% [markdown]
# As noted below, there are 44 and 52 listings contained in the zip codes to compare, which should be sufficient of a sample size to conduct statistical testing.

# %%
prices_97205.shape
# Out:
# (52,)

# %%
prices_97236.shape
# Out:
# (44,)

# %% [markdown]
# I will now determine whether these two populations are normally distributed. If so, I can run a t-test to determine real differences between pricing in the two zip codes. If not, I will run a Mann-Whitney test that does not assume normality.
#
# For the normal distribution test, I will use a QQ plot

# %%
norm_dist52 = np.random.normal(0, 1, 52)
norm_dist52.sort()

# %%
norm_dist44 = np.random.normal(0, 1, 44)
norm_dist44.sort()

# %%
plt.plot(norm_dist52, prices_97205.sort_values(), "o")
plt.show()

# %%
plt.plot(norm_dist44, prices_97236.sort_values(), "o")
plt.show()

# %% [markdown]
# Unfortunately, the zipcode groupings do not appear to be normally distributed, so I'm unable to use the t-test. Instead, I will conduct a Mann-Whitney U test to determine if there are real differences between the listing prices of the two zip codes

# %%
from scipy.stats import mannwhitneyu

print(mannwhitneyu(prices_97205, prices_97236))
# Out:
# MannwhitneyuResult(statistic=254.5, pvalue=2.6976940168325013e-11)

# %% [markdown]
# The prices grouped by zipcode were highly variable, however, it seems that there are very significant differences between them. The Mann-Whitney U test comparing the zipcodes with the highest (97205) and lowest (97236) mean listing price per night indicates the difference between the means are 255 standard errors apart. The p-value is so small, we can be confident that there is a true difference between these two groups.

# %% [markdown]
# ### Question: What other parameters influence price?
#
# To answer this, I will create a correlation heat map.

# %%
# separate out the continuous data into a new dataframe
airbnb_cont = airbnb[['id', 'price', 'host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'guests_included',
                              'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
                              'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
                              'review_scores_value', 'reviews_per_month']].copy()
airbnb_cont.head()
# Out:
#       id  price  host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0   7893  175.0                  1.0             3        1.0       2.0   2.0
# 1  12899   65.0                  1.0             3        1.0       2.0   2.0
# 2  16688  275.0                  1.0             8        2.0       2.0   3.0
# 3  25200   49.0                  7.0             2        1.0       1.0   1.0
# 4  26203   49.0                  7.0             2        1.0       1.0   1.0
#
#    guests_included  minimum_nights  maximum_nights  number_of_reviews  \
# 0                1               3              30                  2
# 1                2               2             730                500
# 2                6               2             365                 44
# 3                1               7            1125                 34
# 4                1               3            1125                 28
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                 100.0                    10.0                       10.0
# 1                  98.0                    10.0                       10.0
# 2                  97.0                    10.0                       10.0
# 3                  93.0                     9.0                        9.0
# 4                  92.0                     9.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                    9.0                         10.0                    10.0
#
#    review_scores_value  reviews_per_month
# 0                 10.0               0.02
# 1                 10.0               4.67
# 2                  9.0               2.37
# 3                  9.0               0.33
# 4                  9.0               0.27

# %%
airbnb_cont_corr = airbnb_cont[list(airbnb_cont.columns)[1:]]
corr = airbnb_cont_corr.corr()
sns.heatmap(corr, 
  xticklabels=corr.columns,
  yticklabels=corr.columns)
plt.show()

# %% [markdown]
# With regards to continuous variables, the highest correlations to listing price are related to how many guests fit in the accomodation: number of bathrooms, bedrooms, beds, and how many guests are included.
#
# Because they are all similar variables that indicate how many guests can fit in a given lodge, I will plot the variable of included guests versus price to verify that a greater amount of guests leads to a higher listing price.

# %%
airbnb.groupby('guests_included').price.mean().plot(kind='bar')
plt.xlabel("Number of guests included")
plt.ylabel("Price per night")
plt.title("Price of a listing based on number of guests included")
plt.yticks(np.arange(0, 600, step=50))
plt.show()

# %% [markdown]
# As to be suspected, the greater the amount of guests a listing can accomodate, the greater the host can charge per night.

# %% [markdown]
# ### Question: Why doesn't high overall reviews lead to a higher cost in price per night?
# A host might expect to increase profits when providing the highest degree of service

# %%
plt.scatter(x='review_scores_rating', y='price', data=airbnb)
plt.xlabel("Review scores rating")
plt.ylabel("Price per night")
plt.title("Price of a listing based on overall review score")
plt.yticks(np.arange(0, 600, step=50))
plt.show()

# %% [markdown]
# It looks like what you pay for is not necessarily what you get with Airbnb. Though one can expect greater than a 90% overall satisfaction if the listing costs between 450 - 500 USD, 100% positive score is found throughout the entire price spectrum. Therefore, a host will want to work very hard in keeping their guests happy if they wish to remain competitive in the market, regardless of lodging cost.

# %% [markdown]
# ## In summary
#
# ### Does location have an effect on Airbnb listing prices?
# There are a wide range of listing prices per night in essentially all zipcodes plotted. It is not necessarily the ultimate determinator of what a host can market price their lodging. However, there are clear differences between the highest and lowest mean priced zipcodes, as verified by the Mann-Whitney U test. In general, it may help to consider the zipcode that a home is in.
#
#
# ### How can one maximize their listing price on Airbnb?
# Variables related to how many guests may be accomodated was the greatest determinant to listing price, with the higher amount of bedrooms, beds, bathrooms, and guests included leading to higher prices.
#
# In addition, host listing count is also linked to listing prices. Perhaps those with more experience in the business either know how to market their accomodations better, maximize space to allow more guests, or select their properties specifically with Airbnb profits in mind.
#
# ### Why doesn't high overall reviews lead to a higher cost in price per night?
# Surprisingly, review scores were not correlated with listing prices. In assessing the review scores data, it seems this is because customers typically give above an 80% review score. These reviews may be overinflated, but Airbnb hosts will want to ensure their guests give high ratings, otherwise future guests may consider going to one of many other place that have a high review at any price range.
#
#
# ## Future work
#
# I believe a host is able to charge more for a stay with them if they provide a greater than average stay. The review scores may be inflated, but it would be interesting to use some Natural Language Processing, or Semantics analysis, to study intricacies in the written review comments between hosts. Perhaps, more of the true experience of the guest would be revealed in the comments. In addition, this data was able to tell us about correlations with listing prices, but not popularity of the AirBnB listings. For instance, anybody can list their spare bedroom that accomodates 2 people for USD500. This would skew our analysis here because it wouldn't consider the fact that nobody is going to book this stay. A better question would be to look at how often a listing be left available versus booked, because this is a better indicator of profitability than listing price alone. For this, I would propose some form of web scraping the Airbnb website, perhaps over a series of months to determine how many days out of these months those listings were left available.
